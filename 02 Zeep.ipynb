# %%
# set connection parameters
UCM_PUBLISHER = 'us-cm-pub.ent-pa.com'
AXL_USER = 'administrator'
AXL_PASSWORD = 'W0rkAllN1ght'

#from connection_parameters import *

# %% [markdown]
# # Using [Zeep](https://github.com/mvantellingen/python-zeep)
#
# Zeep is a SOAP client for Python. Zeep inspects the WSDL document and generates the corresponding code to use the services and types in the WSDL document. This provides an easy to use programmatic interface to a SOAP server.
#
# The output below has been created usigng

# %%
import requests
import os
import zeep
import zeep.cache
import zeep.plugins
import zeep.exceptions
import urllib3
from lxml import etree

# a simple zeep plugin to log all SOAP request and responses to stdin
class LoggingPlugin(zeep.plugins.Plugin):
    @staticmethod
    def print_envelope(header, envelope):
        s = etree.tostring(envelope, pretty_print=True).decode().strip()
        print('\n'.join(f'{header}:{l}' for l in s.splitlines()))

    def ingress(self, envelope, http_headers, operation):
        LoggingPlugin.print_envelope('in', envelope)
        return envelope, http_headers

    def egress(self, envelope, http_headers, operation, binding_options):
        LoggingPlugin.print_envelope('out', envelope)
        return envelope, http_headers
    
# disable warnings for HTTPS sessions w/ diabled cert validation
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

axl_url = f'https://{UCM_PUBLISHER}:8443/axl/'

# we have WSDL files for a number of releases in the WSDL directory
wsdl_version = '11.5'
wsdl = os.path.join('WSDL', wsdl_version, 'AXLAPI.wsdl')
print(f'Using WSDL: {wsdl}')

session = requests.Session()
session.auth = (AXL_USER, AXL_PASSWORD)
session.verify = False

# setting up the zeep client
# - we enable the history plugin so that after calling an endpoint we have access to the latest request & response
# - also we enable our logging plugin above which logs requests and responses in real-time
transport = zeep.Transport(session=session, cache=zeep.cache.SqliteCache())
history = zeep.plugins.HistoryPlugin()
client = zeep.Client(wsdl=wsdl,
                     transport=transport,
                     # create a chain of plugins to keep the history of request/response
                     # and log everything to stdout
                     plugins=[history, LoggingPlugin()])
service = client.create_service('{http://www.cisco.com/AXLAPIService/}AXLAPIBinding', axl_url)
# Out:
# Using WSDL: WSDL/11.5/AXLAPI.wsdl

# %%
tags = 'name clause description dialPlanWizardGenId partitionUsage'

r = service.listCss(searchCriteria={'name':'%'}, returnedTags = {t:'' for t in tags.split()}, first=5)
# Out:
# out:<soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
# out:  <soap-env:Body>
# out:    <ns0:listCss xmlns:ns0="http://www.cisco.com/AXL/API/11.5">
# out:      <searchCriteria>
# out:        <name>%</name>
# out:      </searchCriteria>
# out:      <returnedTags>
# out:        <description></description>
# out:        <clause></clause>
# out:        <dialPlanWizardGenId></dialPlanWizardGenId>
# out:        <partitionUsage></partitionUsage>
# out:        <name></name>
# out:      </returnedTags>
# out:      <first>5</first>
# out:    </ns0:listCss>
# out:  </soap-env:Body>
# out:</soap-env:Envelope>
# in:<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
# in:  <soapenv:Body>
# in:    <ns:listCssResponse xmlns:ns="http://www.cisco.com/AXL/API/11.5">
# in:      <return>
# in:        <css uuid="{04A1F495-55BF-C9E5-9228-14C8E3E3409F}">
# in:          <description>SJC CoS internal</description>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164</clause>
# in:          <dialPlanWizardGenId/>
# in:          <partitionUsage>General</partitionUsage>
# in:          <name>SJCInternal</name>
# in:        </css>
# in:        <css uuid="{0892A0EF-22C7-84C2-F704-79F5EA6D32E2}">
# in:          <description>SJC CoS National</description>
# in:          <clause>DN:Directory URI:ESN:SparkCall:SJCIntra:USPSTNNational:USemergency:UStoE164:onNetRemote:URI</clause>
# in:          <dialPlanWizardGenId/>
# in:          <partitionUsage>General</partitionUsage>
# in:          <name>SJCNational</name>
# in:        </css>
# in:        <css uuid="{0EA6A9D1-DFDA-2C65-70E9-6254DFC03814}">
# in:          <description>RCD CoS International</description>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called</clause>
# in:          <dialPlanWizardGenId/>
# in:          <partitionUsage>General</partitionUsage>
# in:          <name>RCDInternational</name>
# in:        </css>
# in:        <css uuid="{158E5D76-3F81-07CF-63BA-2200AE381A87}">
# in:          <description>PSTN Rerouting</description>
# in:          <clause>PSTNInternational</clause>
# in:          <dialPlanWizardGenId/>
# in:          <partitionUsage>General</partitionUsage>
# in:          <name>PSTNReroute</name>
# in:        </css>
# in:        <css uuid="{16F3FB0F-C231-8ED8-6384-9A095A93A32D}">
# in:          <description>RCD CoS internal</description>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164</clause>
# in:          <dialPlanWizardGenId/>
# in:          <partitionUsage>General</partitionUsage>
# in:          <name>RCDInternal</name>
# in:        </css>
# in:      </return>
# in:    </ns:listCssResponse>
# in:  </soapenv:Body>
# in:</soapenv:Envelope>

# %%
css_list = r['return'].css
print(css_list)
# Out:
# [{
#     'description': 'SJC CoS internal',
#     'clause': 'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164',
#     'dialPlanWizardGenId': None,
#     'partitionUsage': 'General',
#     'name': 'SJCInternal',
#     'uuid': '{04A1F495-55BF-C9E5-9228-14C8E3E3409F}'
# }, {
#     'description': 'SJC CoS National',
#     'clause': 'DN:Directory URI:ESN:SparkCall:SJCIntra:USPSTNNational:USemergency:UStoE164:onNetRemote:URI',
#     'dialPlanWizardGenId': None,
#     'partitionUsage': 'General',
#     'name': 'SJCNational',
#     'uuid': '{0892A0EF-22C7-84C2-F704-79F5EA6D32E2}'
# }, {
#     'description': 'RCD CoS International',
#     'clause': 'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called',
#     'dialPlanWizardGenId': None,
#     'partitionUsage': 'General',
#     'name': 'RCDInternational',
#     'uuid': '{0EA6A9D1-DFDA-2C65-70E9-6254DFC03814}'
# }, {
#     'description': 'PSTN Rerouting',
#     'clause': 'PSTNInternational',
#     'dialPlanWizardGenId': None,
#     'partitionUsage': 'General',
#     'name': 'PSTNReroute',
#     'uuid': '{158E5D76-3F81-07CF-63BA-2200AE381A87}'
# }, {
#     'description': 'RCD CoS internal',
#     'clause': 'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164',
#     'dialPlanWizardGenId': None,
#     'partitionUsage': 'General',
#     'name': 'RCDInternal',
#     'uuid': '{16F3FB0F-C231-8ED8-6384-9A095A93A32D}'
# }]

# %%
print('\n\n'.join(f'{css.name}({css.uuid}): {css.clause}' for css in css_list))
# Out:
# SJCInternal({04A1F495-55BF-C9E5-9228-14C8E3E3409F}): DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164
#
# SJCNational({0892A0EF-22C7-84C2-F704-79F5EA6D32E2}): DN:Directory URI:ESN:SparkCall:SJCIntra:USPSTNNational:USemergency:UStoE164:onNetRemote:URI
#
# RCDInternational({0EA6A9D1-DFDA-2C65-70E9-6254DFC03814}): DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called
#
# PSTNReroute({158E5D76-3F81-07CF-63BA-2200AE381A87}): PSTNInternational
#
# RCDInternal({16F3FB0F-C231-8ED8-6384-9A095A93A32D}): DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164

# %%
print('SOAP Request sent to UCM:')
print(etree.tostring(history.last_sent['envelope'], pretty_print=True).decode())
print('\nSOAP Response received from UCM:')
print(etree.tostring(history.last_received['envelope'], pretty_print=True).decode())
# Out:
# SOAP Request sent to UCM:
# <soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
#   <soap-env:Body>
#     <ns0:listCss xmlns:ns0="http://www.cisco.com/AXL/API/11.5">
#       <searchCriteria>
#         <name>%</name>
#       </searchCriteria>
#       <returnedTags>
#         <description></description>
#         <clause></clause>
#         <dialPlanWizardGenId></dialPlanWizardGenId>
#         <partitionUsage></partitionUsage>
#         <name></name>
#       </returnedTags>
#       <first>5</first>
#     </ns0:listCss>
#   </soap-env:Body>
# </soap-env:Envelope>
#
#
# SOAP Response received from UCM:
# <soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
#   <soapenv:Body>
#     <ns:listCssResponse xmlns:ns="http://www.cisco.com/AXL/API/11.5">
#       <return>
#         <css uuid="{04A1F495-55BF-C9E5-9228-14C8E3E3409F}">
#           <description>SJC CoS internal</description>
#           <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164</clause>
#           <dialPlanWizardGenId/>
#           <partitionUsage>General</partitionUsage>
#           <name>SJCInternal</name>
#         </css>
#         <css uuid="{0892A0EF-22C7-84C2-F704-79F5EA6D32E2}">
#           <description>SJC CoS National</description>
#           <clause>DN:Directory URI:ESN:SparkCall:SJCIntra:USPSTNNational:USemergency:UStoE164:onNetRemote:URI</clause>
#           <dialPlanWizardGenId/>
#           <partitionUsage>General</partitionUsage>
#           <name>SJCNational</name>
#         </css>
#         <css uuid="{0EA6A9D1-DFDA-2C65-70E9-6254DFC03814}">
#           <description>RCD CoS International</description>
#           <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called</clause>
#           <dialPlanWizardGenId/>
#           <partitionUsage>General</partitionUsage>
#           <name>RCDInternational</name>
#         </css>
#         <css uuid="{158E5D76-3F81-07CF-63BA-2200AE381A87}">
#           <description>PSTN Rerouting</description>
#           <clause>PSTNInternational</clause>
#           <dialPlanWizardGenId/>
#           <partitionUsage>General</partitionUsage>
#           <name>PSTNReroute</name>
#         </css>
#         <css uuid="{16F3FB0F-C231-8ED8-6384-9A095A93A32D}">
#           <description>RCD CoS internal</description>
#           <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164</clause>
#           <dialPlanWizardGenId/>
#           <partitionUsage>General</partitionUsage>
#           <name>RCDInternal</name>
#         </css>
#       </return>
#     </ns:listCssResponse>
#   </soapenv:Body>
# </soapenv:Envelope>

# %% [markdown]
# # Executing SQL Queries
#
# The [database dictionary](https://developer.cisco.com/docs/axl/#!12-5-cucm-data-dictionary) describes all tables in the UCM database and the relations between these tables.
#
# The [executeSQLQuery](https://pubhub.devnetcloud.com/media/axl-schema-reference/docs/Files/AXLSoap_executeSQLQuery.html#Link45E) and [updateSQLQuery](https://pubhub.devnetcloud.com/media/axl-schema-reference/docs/Files/AXLSoap_executeSQLUpdate.html#Link466) methods enable direct access to the UCM database.

# %%
r = service.executeSQLQuery(sql='select * from processnode')
# Out:
# out:<soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
# out:  <soap-env:Body>
# out:    <ns0:executeSQLQuery xmlns:ns0="http://www.cisco.com/AXL/API/11.5">
# out:      <sql>select * from processnode</sql>
# out:    </ns0:executeSQLQuery>
# out:  </soap-env:Body>
# out:</soap-env:Envelope>
# in:<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
# in:  <soapenv:Body>
# in:    <ns:executeSQLQueryResponse xmlns:ns="http://www.cisco.com/AXL/API/11.5">
# in:      <return>
# in:        <row>
# in:          <pkid>00000000-1111-0000-0000-000000000000</pkid>
# in:          <name>EnterpriseWideData</name>
# in:          <mac/>
# in:          <systemnode>t</systemnode>
# in:          <description/>
# in:          <isactive>t</isactive>
# in:          <nodeid>1</nodeid>
# in:          <tknodeusage>1</tknodeusage>
# in:          <ipv6name/>
# in:          <fklbmhubgroup/>
# in:          <tkprocessnoderole>1</tkprocessnoderole>
# in:          <tkssomode>0</tkssomode>
# in:        </row>
# in:        <row>
# in:          <pkid>0c083472-2718-e161-5ce2-0bdf2fd08a27</pkid>
# in:          <name>us-cm-tftp1.ent-pa.com</name>
# in:          <mac/>
# in:          <systemnode>f</systemnode>
# in:          <description/>
# in:          <isactive>t</isactive>
# in:          <nodeid>7</nodeid>
# in:          <tknodeusage>1</tknodeusage>
# in:          <ipv6name/>
# in:          <fklbmhubgroup/>
# in:          <tkprocessnoderole>1</tkprocessnoderole>
# in:          <tkssomode>2</tkssomode>
# in:        </row>
# in:        <row>
# in:          <pkid>3e49d44a-4608-cfb3-7f2e-9737c3076af4</pkid>
# in:          <name>us-imp-sub1.ent-pa.com</name>
# in:          <mac/>
# in:          <systemnode>f</systemnode>
# in:          <description/>
# in:          <isactive>t</isactive>
# in:          <nodeid>5</nodeid>
# in:          <tknodeusage>1</tknodeusage>
# in:          <ipv6name/>
# in:          <fklbmhubgroup/>
# in:          <tkprocessnoderole>2</tkprocessnoderole>
# in:          <tkssomode>2</tkssomode>
# in:        </row>
# in:        <row>
# in:          <pkid>967433f9-cccf-4401-883d-b2eabd335cde</pkid>
# in:          <name>us-cm-pub.ent-pa.com</name>
# in:          <mac/>
# in:          <systemnode>f</systemnode>
# in:          <description/>
# in:          <isactive>t</isactive>
# in:          <nodeid>2</nodeid>
# in:          <tknodeusage>0</tknodeusage>
# in:          <ipv6name/>
# in:          <fklbmhubgroup/>
# in:          <tkprocessnoderole>1</tkprocessnoderole>
# in:          <tkssomode>2</tkssomode>
# in:        </row>
# in:        <row>
# in:          <pkid>aef3530b-6588-08cd-3bc5-3582cf5550ad</pkid>
# in:          <name>us-cm-sub2.ent-pa.com</name>
# in:          <mac/>
# in:          <systemnode>f</systemnode>
# in:          <description/>
# in:          <isactive>t</isactive>
# in:          <nodeid>6</nodeid>
# in:          <tknodeusage>1</tknodeusage>
# in:          <ipv6name/>
# in:          <fklbmhubgroup/>
# in:          <tkprocessnoderole>1</tkprocessnoderole>
# in:          <tkssomode>2</tkssomode>
# in:        </row>
# in:        <row>
# in:          <pkid>b5dc9f52-7c8a-171f-7063-82365cb28639</pkid>
# in:          <name>us-imp-pub.ent-pa.com</name>
# in:          <mac/>
# in:          <systemnode>f</systemnode>
# in:          <description/>
# in:          <isactive>t</isactive>
# in:          <nodeid>4</nodeid>
# in:          <tknodeusage>0</tknodeusage>
# in:          <ipv6name/>
# in:          <fklbmhubgroup/>
# in:          <tkprocessnoderole>2</tkprocessnoderole>
# in:          <tkssomode>2</tkssomode>
# in:        </row>
# in:        <row>
# in:          <pkid>f1261698-420e-4da7-a9db-9963296c28a5</pkid>
# in:          <name>us-cm-sub1.ent-pa.com</name>
# in:          <mac/>
# in:          <systemnode>f</systemnode>
# in:          <description/>
# in:          <isactive>t</isactive>
# in:          <nodeid>3</nodeid>
# in:          <tknodeusage>1</tknodeusage>
# in:          <ipv6name/>
# in:          <fklbmhubgroup>e87ffdf1-db5c-42d8-523a-bcdba060c2e6</fklbmhubgroup>
# in:          <tkprocessnoderole>1</tkprocessnoderole>
# in:          <tkssomode>2</tkssomode>
# in:        </row>
# in:      </return>
# in:    </ns:executeSQLQueryResponse>
# in:  </soapenv:Body>
# in:</soapenv:Envelope>

# %%
rows = r['return'].row
rows
# Out:
# [[<Element pkid at 0x115a7cf00>,
#   <Element name at 0x115a7cf50>,
#   <Element mac at 0x115a7cfa0>,
#   <Element systemnode at 0x115a7cb90>,
#   <Element description at 0x115a7c0f0>,
#   <Element isactive at 0x115a7c050>,
#   <Element nodeid at 0x115a7c140>,
#   <Element tknodeusage at 0x115a7c190>,
#   <Element ipv6name at 0x115a7c1e0>,
#   <Element fklbmhubgroup at 0x115a7c230>,
#   <Element tkprocessnoderole at 0x115a7c280>,
#   <Element tkssomode at 0x115a7c2d0>],
#  [<Element pkid at 0x115a7c320>,
#   <Element name at 0x115a7c370>,
#   <Element mac at 0x115a7c3c0>,
#   <Element systemnode at 0x115a7c410>,
#   <Element description at 0x115a7c460>,
#   <Element isactive at 0x115a7c4b0>,
#   <Element nodeid at 0x115a7c500>,
#   <Element tknodeusage at 0x115a7c550>,
#   <Element ipv6name at 0x115a7c5a0>,
#   <Element fklbmhubgroup at 0x115a7c5f0>,
#   <Element tkprocessnoderole at 0x115a7c640>,
#   <Element tkssomode at 0x115a7c690>],
#  [<Element pkid at 0x115a7c6e0>,
#   <Element name at 0x115a7c730>,
#   <Element mac at 0x115a7c780>,
#   <Element systemnode at 0x115a7c7d0>,
#   <Element description at 0x115a7c820>,
#   <Element isactive at 0x115a7c870>,
#   <Element nodeid at 0x115a7c8c0>,
#   <Element tknodeusage at 0x115a7c910>,
#   <Element ipv6name at 0x115a7c960>,
#   <Element fklbmhubgroup at 0x115a7c9b0>,
#   <Element tkprocessnoderole at 0x115a7ca00>,
#   <Element tkssomode at 0x115a7ca50>],
#  [<Element pkid at 0x115a7caa0>,
#   <Element name at 0x115a7caf0>,
#   <Element mac at 0x115a7cb40>,
#   <Element systemnode at 0x115a7f050>,
#   <Element description at 0x115a7f0a0>,
#   <Element isactive at 0x115a7f0f0>,
#   <Element nodeid at 0x115a7f140>,
#   <Element tknodeusage at 0x115a7f190>,
#   <Element ipv6name at 0x115a7f1e0>,
#   <Element fklbmhubgroup at 0x115a7f230>,
#   <Element tkprocessnoderole at 0x115a7f280>,
#   <Element tkssomode at 0x115a7f2d0>],
#  [<Element pkid at 0x115a7f320>,
#   <Element name at 0x115a7f370>,
#   <Element mac at 0x115a7f3c0>,
#   <Element systemnode at 0x115a7f410>,
#   <Element description at 0x115a7f460>,
#   <Element isactive at 0x115a7f4b0>,
#   <Element nodeid at 0x115a7f500>,
#   <Element tknodeusage at 0x115a7f550>,
#   <Element ipv6name at 0x115a7f5a0>,
#   <Element fklbmhubgroup at 0x115a7f5f0>,
#   <Element tkprocessnoderole at 0x115a7f640>,
#   <Element tkssomode at 0x115a7f690>],
#  [<Element pkid at 0x115a7f6e0>,
#   <Element name at 0x115a7f730>,
#   <Element mac at 0x115a7f780>,
#   <Element systemnode at 0x115a7f7d0>,
#   <Element description at 0x115a7f820>,
#   <Element isactive at 0x115a7f870>,
#   <Element nodeid at 0x115a7f8c0>,
#   <Element tknodeusage at 0x115a7f910>,
#   <Element ipv6name at 0x115a7f960>,
#   <Element fklbmhubgroup at 0x115a7f9b0>,
#   <Element tkprocessnoderole at 0x115a7fa00>,
#   <Element tkssomode at 0x115a7fa50>],
#  [<Element pkid at 0x115a7faa0>,
#   <Element name at 0x115a7faf0>,
#   <Element mac at 0x115a7fb40>,
#   <Element systemnode at 0x115a7fb90>,
#   <Element description at 0x115a7fbe0>,
#   <Element isactive at 0x115a7fc30>,
#   <Element nodeid at 0x115a7fc80>,
#   <Element tknodeusage at 0x115a7a410>,
#   <Element ipv6name at 0x115a7a3c0>,
#   <Element fklbmhubgroup at 0x115a7a1e0>,
#   <Element tkprocessnoderole at 0x115a7a370>,
#   <Element tkssomode at 0x115a73dc0>]]

# %% [markdown]
# Not very helpful. We'd prefer to have a list of objects which allow to access the returned values as attributes

# %%
class Row:
    # Helper class to create an object based on a row returned from an AXL executeSqlQuery
    def __init__(self, row):
        # save a dictionary of key/value pairs
        self._obj =  {e.tag:e.text for e in row}

    def __repr__(self):
        """
        String representation for row object
        :return:
        """
        return f'Row({", ".join(f"{k}={v}" for k,v in self._obj.items())})'

    def __getattr__(self, item):
        """
        Satisfy attribute access by accessing saved directory
        :param item:
        :return:
        """
        return self._obj[item]

# %%
rows = [Row(r) for r in rows]

# %% [markdown]
# The `Row` helper class also allows us to access the values in the rows as attributes.

# %%
names = [r.name for r in rows]
names
# Out:
# ['EnterpriseWideData',
#  'us-cm-tftp1.ent-pa.com',
#  'us-imp-sub1.ent-pa.com',
#  'us-cm-pub.ent-pa.com',
#  'us-cm-sub2.ent-pa.com',
#  'us-imp-pub.ent-pa.com',
#  'us-cm-sub1.ent-pa.com']

# %% [markdown]
# ... and the `__repr__` method implementation gives us a readable representation of the rows

# %%
print('\n'.join(str(r) for r in rows))
# Out:
# Row(pkid=00000000-1111-0000-0000-000000000000, name=EnterpriseWideData, mac=None, systemnode=t, description=None, isactive=t, nodeid=1, tknodeusage=1, ipv6name=None, fklbmhubgroup=None, tkprocessnoderole=1, tkssomode=0)
# Row(pkid=0c083472-2718-e161-5ce2-0bdf2fd08a27, name=us-cm-tftp1.ent-pa.com, mac=None, systemnode=f, description=None, isactive=t, nodeid=7, tknodeusage=1, ipv6name=None, fklbmhubgroup=None, tkprocessnoderole=1, tkssomode=2)
# Row(pkid=3e49d44a-4608-cfb3-7f2e-9737c3076af4, name=us-imp-sub1.ent-pa.com, mac=None, systemnode=f, description=None, isactive=t, nodeid=5, tknodeusage=1, ipv6name=None, fklbmhubgroup=None, tkprocessnoderole=2, tkssomode=2)
# Row(pkid=967433f9-cccf-4401-883d-b2eabd335cde, name=us-cm-pub.ent-pa.com, mac=None, systemnode=f, description=None, isactive=t, nodeid=2, tknodeusage=0, ipv6name=None, fklbmhubgroup=None, tkprocessnoderole=1, tkssomode=2)
# Row(pkid=aef3530b-6588-08cd-3bc5-3582cf5550ad, name=us-cm-sub2.ent-pa.com, mac=None, systemnode=f, description=None, isactive=t, nodeid=6, tknodeusage=1, ipv6name=None, fklbmhubgroup=None, tkprocessnoderole=1, tkssomode=2)
# Row(pkid=b5dc9f52-7c8a-171f-7063-82365cb28639, name=us-imp-pub.ent-pa.com, mac=None, systemnode=f, description=None, isactive=t, nodeid=4, tknodeusage=0, ipv6name=None, fklbmhubgroup=None, tkprocessnoderole=2, tkssomode=2)
# Row(pkid=f1261698-420e-4da7-a9db-9963296c28a5, name=us-cm-sub1.ent-pa.com, mac=None, systemnode=f, description=None, isactive=t, nodeid=3, tknodeusage=1, ipv6name=None, fklbmhubgroup=e87ffdf1-db5c-42d8-523a-bcdba060c2e6, tkprocessnoderole=1, tkssomode=2)

# %% [markdown]
# Here's how we could get a list of CSSes using thin AXL. This is (more or less) equivalent to the listCss above.

# %%
r = service.executeSQLQuery(sql='select name,clause from callingsearchspace')
rows = [Row(r) for r in r['return'].row]
# Out:
# out:<soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
# out:  <soap-env:Body>
# out:    <ns0:executeSQLQuery xmlns:ns0="http://www.cisco.com/AXL/API/11.5">
# out:      <sql>select name,clause from callingsearchspace</sql>
# out:    </ns0:executeSQLQuery>
# out:  </soap-env:Body>
# out:</soap-env:Envelope>
# in:<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
# in:  <soapenv:Body>
# in:    <ns:executeSQLQueryResponse xmlns:ns="http://www.cisco.com/AXL/API/11.5">
# in:      <return>
# in:        <row>
# in:          <name>SJCInternal</name>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164</clause>
# in:        </row>
# in:        <row>
# in:          <name>SJCNational</name>
# in:          <clause>DN:Directory URI:ESN:SparkCall:SJCIntra:USPSTNNational:USemergency:UStoE164:onNetRemote:URI</clause>
# in:        </row>
# in:        <row>
# in:          <name>RCDInternational</name>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called</clause>
# in:        </row>
# in:        <row>
# in:          <name>PSTNReroute</name>
# in:          <clause>PSTNInternational</clause>
# in:        </row>
# in:        <row>
# in:          <name>RCDInternal</name>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164</clause>
# in:        </row>
# in:        <row>
# in:          <name>RTPInternational</name>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called</clause>
# in:        </row>
# in:        <row>
# in:          <name>RCDLocal</name>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:RCDPSTNLocal</clause>
# in:        </row>
# in:        <row>
# in:          <name>Enterprise_CSS</name>
# in:          <clause>DN</clause>
# in:        </row>
# in:        <row>
# in:          <name>DN</name>
# in:          <clause>DN</clause>
# in:        </row>
# in:        <row>
# in:          <name>SJCPhLocalize</name>
# in:          <clause>USPhLocalize:SJCPhLocalize</clause>
# in:        </row>
# in:        <row>
# in:          <name>ICTInbound</name>
# in:          <clause>ESN:SparkCall:Directory URI:URI:DN</clause>
# in:        </row>
# in:        <row>
# in:          <name>USemergency</name>
# in:          <clause>USemergency</clause>
# in:        </row>
# in:        <row>
# in:          <name>DefaultSubscribe</name>
# in:          <clause>DN:ESN:URI:onNetRemote:Directory URI</clause>
# in:        </row>
# in:        <row>
# in:          <name>SJCLocal</name>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164:SJCPSTNLocal</clause>
# in:        </row>
# in:        <row>
# in:          <name>Internet_inbound</name>
# in:          <clause>DN:Directory URI</clause>
# in:        </row>
# in:        <row>
# in:          <name>RTPLocal</name>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164:RTPPSTNLocal</clause>
# in:        </row>
# in:        <row>
# in:          <name>RCDNational</name>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:USPSTNNational</clause>
# in:        </row>
# in:        <row>
# in:          <name>RCDPhLocalize</name>
# in:          <clause>USPhLocalize:RCDPhLocalize</clause>
# in:        </row>
# in:        <row>
# in:          <name>Block_All</name>
# in:          <clause/>
# in:        </row>
# in:        <row>
# in:          <name>CloudSIPURI</name>
# in:          <clause/>
# in:        </row>
# in:        <row>
# in:          <name>RTPPhLocalize</name>
# in:          <clause>USPhLocalize:RTPPhLocalize</clause>
# in:        </row>
# in:        <row>
# in:          <name>UnityConnection</name>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:UStoE164</clause>
# in:        </row>
# in:        <row>
# in:          <name>RTPNational</name>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164:USPSTNNational</clause>
# in:        </row>
# in:        <row>
# in:          <name>RTPInternal</name>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164</clause>
# in:        </row>
# in:        <row>
# in:          <name>SJCInternational</name>
# in:          <clause>DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called</clause>
# in:        </row>
# in:        <row>
# in:          <name>SparkInbound</name>
# in:          <clause>ESN:Directory URI:URI:DN:SparkCall</clause>
# in:        </row>
# in:        <row>
# in:          <name>TelePresenceConferencing</name>
# in:          <clause>DN:Directory URI:ESN:SparkCall:URI:onNetRemote:PSTNInternational</clause>
# in:        </row>
# in:        <row>
# in:          <name>Webex_Calling</name>
# in:          <clause>DN:ESN:PSTNInternational:onNetRemote</clause>
# in:        </row>
# in:      </return>
# in:    </ns:executeSQLQueryResponse>
# in:  </soapenv:Body>
# in:</soapenv:Envelope>

# %%
print(rows)
# Out:
# [Row(name=SJCInternal, clause=DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164), Row(name=SJCNational, clause=DN:Directory URI:ESN:SparkCall:SJCIntra:USPSTNNational:USemergency:UStoE164:onNetRemote:URI), Row(name=RCDInternational, clause=DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called), Row(name=PSTNReroute, clause=PSTNInternational), Row(name=RCDInternal, clause=DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164), Row(name=RTPInternational, clause=DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called), Row(name=RCDLocal, clause=DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:RCDPSTNLocal), Row(name=Enterprise_CSS, clause=DN), Row(name=DN, clause=DN), Row(name=SJCPhLocalize, clause=USPhLocalize:SJCPhLocalize), Row(name=ICTInbound, clause=ESN:SparkCall:Directory URI:URI:DN), Row(name=USemergency, clause=USemergency), Row(name=DefaultSubscribe, clause=DN:ESN:URI:onNetRemote:Directory URI), Row(name=SJCLocal, clause=DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164:SJCPSTNLocal), Row(name=Internet_inbound, clause=DN:Directory URI), Row(name=RTPLocal, clause=DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164:RTPPSTNLocal), Row(name=RCDNational, clause=DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:USPSTNNational), Row(name=RCDPhLocalize, clause=USPhLocalize:RCDPhLocalize), Row(name=Block_All, clause=None), Row(name=CloudSIPURI, clause=None), Row(name=RTPPhLocalize, clause=USPhLocalize:RTPPhLocalize), Row(name=UnityConnection, clause=DN:Directory URI:URI:ESN:SparkCall:onNetRemote:UStoE164), Row(name=RTPNational, clause=DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164:USPSTNNational), Row(name=RTPInternal, clause=DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164), Row(name=SJCInternational, clause=DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called), Row(name=SparkInbound, clause=ESN:Directory URI:URI:DN:SparkCall), Row(name=TelePresenceConferencing, clause=DN:Directory URI:ESN:SparkCall:URI:onNetRemote:PSTNInternational), Row(name=Webex_Calling, clause=DN:ESN:PSTNInternational:onNetRemote)]

# %% [markdown]
# Using simple thin AXL request we can easily execute some validations on the configured CSSes
#
# For example: **Are there any CSSes without partitions assigned to them?**

# %%
csses_wo_partitions = [css.name for css in rows if css.clause is None]
print(f'CSSes w/o partitions: {", ".join(csses_wo_partitions)}')
# Out:
# CSSes w/o partitions: Block_All, CloudSIPURI

# %% [markdown]
# .. or: **Are there partitions which are not used in any CSS?**

# %%
import itertools

# let's try to determine the set of partitions used in CSSes
clauses = [r.clause for r in rows]
clauses
# Out:
# ['DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164',
#  'DN:Directory URI:ESN:SparkCall:SJCIntra:USPSTNNational:USemergency:UStoE164:onNetRemote:URI',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called',
#  'PSTNInternational',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:RCDPSTNLocal',
#  'DN',
#  'DN',
#  'USPhLocalize:SJCPhLocalize',
#  'ESN:SparkCall:Directory URI:URI:DN',
#  'USemergency',
#  'DN:ESN:URI:onNetRemote:Directory URI',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164:SJCPSTNLocal',
#  'DN:Directory URI',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164:RTPPSTNLocal',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:USPSTNNational',
#  'USPhLocalize:RCDPhLocalize',
#  None,
#  None,
#  'USPhLocalize:RTPPhLocalize',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:UStoE164',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164:USPSTNNational',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called',
#  'ESN:Directory URI:URI:DN:SparkCall',
#  'DN:Directory URI:ESN:SparkCall:URI:onNetRemote:PSTNInternational',
#  'DN:ESN:PSTNInternational:onNetRemote']

# %%
# only not empty clauses
clauses = [c for c in clauses if c is not None]
clauses
# Out:
# ['DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164',
#  'DN:Directory URI:ESN:SparkCall:SJCIntra:USPSTNNational:USemergency:UStoE164:onNetRemote:URI',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called',
#  'PSTNInternational',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:RCDPSTNLocal',
#  'DN',
#  'DN',
#  'USPhLocalize:SJCPhLocalize',
#  'ESN:SparkCall:Directory URI:URI:DN',
#  'USemergency',
#  'DN:ESN:URI:onNetRemote:Directory URI',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164:SJCPSTNLocal',
#  'DN:Directory URI',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164:RTPPSTNLocal',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RCDIntra:UStoE164:USPSTNNational',
#  'USPhLocalize:RCDPhLocalize',
#  'USPhLocalize:RTPPhLocalize',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:UStoE164',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164:USPSTNNational',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:RTPIntra:UStoE164',
#  'DN:Directory URI:URI:ESN:SparkCall:onNetRemote:SJCIntra:UStoE164:PSTNInternational:USPSTNNational:B2B_URI:edge nearest to the called',
#  'ESN:Directory URI:URI:DN:SparkCall',
#  'DN:Directory URI:ESN:SparkCall:URI:onNetRemote:PSTNInternational',
#  'DN:ESN:PSTNInternational:onNetRemote']

# %%
# get partition names by splitting at ':'
# this creates a list of lists of strings
clauses = [c.split(':') for c in clauses]
clauses
# Out:
# [['DN',
#   'Directory URI',
#   'URI',
#   'ESN',
#   'SparkCall',
#   'onNetRemote',
#   'SJCIntra',
#   'UStoE164'],
#  ['DN',
#   'Directory URI',
#   'ESN',
#   'SparkCall',
#   'SJCIntra',
#   'USPSTNNational',
#   'USemergency',
#   'UStoE164',
#   'onNetRemote',
#   'URI'],
#  ['DN',
#   'Directory URI',
#   'URI',
#   'ESN',
#   'SparkCall',
#   'onNetRemote',
#   'RCDIntra',
#   'UStoE164',
#   'PSTNInternational',
#   'USPSTNNational',
#   'B2B_URI',
#   'edge nearest to the called'],
#  ['PSTNInternational'],
#  ['DN',
#   'Directory URI',
#   'URI',
#   'ESN',
#   'SparkCall',
#   'onNetRemote',
#   'RCDIntra',
#   'UStoE164'],
#  ['DN',
#   'Directory URI',
#   'URI',
#   'ESN',
#   'SparkCall',
#   'onNetRemote',
#   'RTPIntra',
#   'UStoE164',
#   'PSTNInternational',
#   'USPSTNNational',
#   'B2B_URI',
#   'edge nearest to the called'],
#  ['DN',
#   'Directory URI',
#   'URI',
#   'ESN',
#   'SparkCall',
#   'onNetRemote',
#   'RCDIntra',
#   'UStoE164',
#   'RCDPSTNLocal'],
#  ['DN'],
#  ['DN'],
#  ['USPhLocalize', 'SJCPhLocalize'],
#  ['ESN', 'SparkCall', 'Directory URI', 'URI', 'DN'],
#  ['USemergency'],
#  ['DN', 'ESN', 'URI', 'onNetRemote', 'Directory URI'],
#  ['DN',
#   'Directory URI',
#   'URI',
#   'ESN',
#   'SparkCall',
#   'onNetRemote',
#   'SJCIntra',
#   'UStoE164',
#   'SJCPSTNLocal'],
#  ['DN', 'Directory URI'],
#  ['DN',
#   'Directory URI',
#   'URI',
#   'ESN',
#   'SparkCall',
#   'onNetRemote',
#   'RTPIntra',
#   'UStoE164',
#   'RTPPSTNLocal'],
#  ['DN',
#   'Directory URI',
#   'URI',
#   'ESN',
#   'SparkCall',
#   'onNetRemote',
#   'RCDIntra',
#   'UStoE164',
#   'USPSTNNational'],
#  ['USPhLocalize', 'RCDPhLocalize'],
#  ['USPhLocalize', 'RTPPhLocalize'],
#  ['DN', 'Directory URI', 'URI', 'ESN', 'SparkCall', 'onNetRemote', 'UStoE164'],
#  ['DN',
#   'Directory URI',
#   'URI',
#   'ESN',
#   'SparkCall',
#   'onNetRemote',
#   'RTPIntra',
#   'UStoE164',
#   'USPSTNNational'],
#  ['DN',
#   'Directory URI',
#   'URI',
#   'ESN',
#   'SparkCall',
#   'onNetRemote',
#   'RTPIntra',
#   'UStoE164'],
#  ['DN',
#   'Directory URI',
#   'URI',
#   'ESN',
#   'SparkCall',
#   'onNetRemote',
#   'SJCIntra',
#   'UStoE164',
#   'PSTNInternational',
#   'USPSTNNational',
#   'B2B_URI',
#   'edge nearest to the called'],
#  ['ESN', 'Directory URI', 'URI', 'DN', 'SparkCall'],
#  ['DN',
#   'Directory URI',
#   'ESN',
#   'SparkCall',
#   'URI',
#   'onNetRemote',
#   'PSTNInternational'],
#  ['DN', 'ESN', 'PSTNInternational', 'onNetRemote']]

# %%
# now chain all partition names, put them in a set to make them unique
# also it's fast to check whether a partition is in the set
used_partitions = set(itertools.chain.from_iterable(clauses))
used_partitions
# Out:
# {'B2B_URI',
#  'DN',
#  'Directory URI',
#  'ESN',
#  'PSTNInternational',
#  'RCDIntra',
#  'RCDPSTNLocal',
#  'RCDPhLocalize',
#  'RTPIntra',
#  'RTPPSTNLocal',
#  'RTPPhLocalize',
#  'SJCIntra',
#  'SJCPSTNLocal',
#  'SJCPhLocalize',
#  'SparkCall',
#  'URI',
#  'USPSTNNational',
#  'USPhLocalize',
#  'USemergency',
#  'UStoE164',
#  'edge nearest to the called',
#  'onNetRemote'}

# %%
# Get all partition names
r = service.executeSQLQuery(sql='select name from routepartition')
partition_names = [row[0].text for row in r['return'].row]
partition_names
# Out:
# out:<soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
# out:  <soap-env:Body>
# out:    <ns0:executeSQLQuery xmlns:ns0="http://www.cisco.com/AXL/API/11.5">
# out:      <sql>select name from routepartition</sql>
# out:    </ns0:executeSQLQuery>
# out:  </soap-env:Body>
# out:</soap-env:Envelope>
# in:<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
# in:  <soapenv:Body>
# in:    <ns:executeSQLQueryResponse xmlns:ns="http://www.cisco.com/AXL/API/11.5">
# in:      <return>
# in:        <row>
# in:          <name>SJCIntra</name>
# in:        </row>
# in:        <row>
# in:          <name>RTPIntra</name>
# in:        </row>
# in:        <row>
# in:          <name>PSTNInternational</name>
# in:        </row>
# in:        <row>
# in:          <name>USPhLocalize</name>
# in:        </row>
# in:        <row>
# in:          <name>Global Learned E164 Numbers</name>
# in:        </row>
# in:        <row>
# in:          <name>SJCPSTNLocal</name>
# in:        </row>
# in:        <row>
# in:          <name>RCDIntra</name>
# in:        </row>
# in:        <row>
# in:          <name>RTPPSTNLocal</name>
# in:        </row>
# in:        <row>
# in:          <name>Auto-registration_Pt</name>
# in:        </row>
# in:        <row>
# in:          <name>URI</name>
# in:        </row>
# in:        <row>
# in:          <name>ent-pacom</name>
# in:        </row>
# in:        <row>
# in:          <name>loopavoidance</name>
# in:        </row>
# in:        <row>
# in:          <name>B2B_URI</name>
# in:        </row>
# in:        <row>
# in:          <name>Global Learned Enterprise Patterns</name>
# in:        </row>
# in:        <row>
# in:          <name>DN</name>
# in:        </row>
# in:        <row>
# in:          <name>Global Learned Enterprise Numbers</name>
# in:        </row>
# in:        <row>
# in:          <name>RCDPSTNLocal</name>
# in:        </row>
# in:        <row>
# in:          <name>Global Learned E164 Patterns</name>
# in:        </row>
# in:        <row>
# in:          <name>onNetRemote</name>
# in:        </row>
# in:        <row>
# in:          <name>SparkCall</name>
# in:        </row>
# in:        <row>
# in:          <name>UStoE164</name>
# in:        </row>
# in:        <row>
# in:          <name>Directory URI</name>
# in:        </row>
# in:        <row>
# in:          <name>SJCPhLocalize</name>
# in:        </row>
# in:        <row>
# in:          <name>RTPPhLocalize</name>
# in:        </row>
# in:        <row>
# in:          <name>edge nearest to the called</name>
# in:        </row>
# in:        <row>
# in:          <name>RCDPhLocalize</name>
# in:        </row>
# in:        <row>
# in:          <name>USemergency</name>
# in:        </row>
# in:        <row>
# in:          <name>USPSTNNational</name>
# in:        </row>
# in:        <row>
# in:          <name>ESN</name>
# in:        </row>
# in:        <row>
# in:          <name>Webex_Calling</name>
# in:        </row>
# in:        <row>
# in:          <name>blockmobile</name>
# in:        </row>
# in:      </return>
# in:    </ns:executeSQLQueryResponse>
# in:  </soapenv:Body>
# in:</soapenv:Envelope>
# ['SJCIntra',
#  'RTPIntra',
#  'PSTNInternational',
#  'USPhLocalize',
#  'Global Learned E164 Numbers',
#  'SJCPSTNLocal',
#  'RCDIntra',
#  'RTPPSTNLocal',
#  'Auto-registration_Pt',
#  'URI',
#  'ent-pacom',
#  'loopavoidance',
#  'B2B_URI',
#  'Global Learned Enterprise Patterns',
#  'DN',
#  'Global Learned Enterprise Numbers',
#  'RCDPSTNLocal',
#  'Global Learned E164 Patterns',
#  'onNetRemote',
#  'SparkCall',
#  'UStoE164',
#  'Directory URI',
#  'SJCPhLocalize',
#  'RTPPhLocalize',
#  'edge nearest to the called',
#  'RCDPhLocalize',
#  'USemergency',
#  'USPSTNNational',
#  'ESN',
#  'Webex_Calling',
#  'blockmobile']

# %%
# are there any partitions which are not used in any CSS?
unused_partitions = [p for p in partition_names if p not in used_partitions]
print(f'Partitions not used in any CSS: {", ".join(unused_partitions)}')
# Out:
# Partitions not used in any CSS: Global Learned E164 Numbers, Auto-registration_Pt, ent-pacom, loopavoidance, Global Learned Enterprise Patterns, Global Learned Enterprise Numbers, Global Learned E164 Patterns, Webex_Calling, blockmobile

# %% [markdown]
# In principle complex SQL statements can be used to execute more advanced queries. Multiple tables can be joined using the information published in the data dictionary:
#
# ## Table Relationships
#
# **pkid** is the primary key ID. It is always of type GUID (a 36 character UUID).
#
# Fields that begin with the letters "**fk**" represent foriegn keys into another table. The name of the field following the "fk" prefix up to but not including an underscore character is the name of the related table. The field in related table is always pkid. and is a GUID.
#
# Fields that begin with the letters "**ik**" represent internal keys into the same table.
#
# Fields that begin with a "**tk**" represent an enumerated type. This field is related to a table whose name begins with "Type" and ends with the name of the field following the prefix up to but not including an underscore character. The field in the related table is always "enum" and is an integer.
#
#
# Using this information this SQL query combines the `numplan` and `typepatternusage` tables and selects a list of directory numbers starting with +1919 in ascending order:
# ```
# select dnorpattern from numplan np left join typepatternusage tpu on np.tkpatternusage=tpu.enum where tpu.name="Device" and dnorpattern like "%+1919%" order by dnorpattern
# ```

# %%
r = service.executeSQLQuery('select dnorpattern,tkpatternusage from numplan np left join typepatternusage tpu on np.tkpatternusage=tpu.enum where tpu.name="Device" and dnorpattern like "%+1919%" order by dnorpattern')
# Out:
# out:<soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
# out:  <soap-env:Body>
# out:    <ns0:executeSQLQuery xmlns:ns0="http://www.cisco.com/AXL/API/11.5">
# out:      <sql>select dnorpattern,tkpatternusage from numplan np left join typepatternusage tpu on np.tkpatternusage=tpu.enum where tpu.name="Device" and dnorpattern like "%+1919%" order by dnorpattern</sql>
# out:    </ns0:executeSQLQuery>
# out:  </soap-env:Body>
# out:</soap-env:Envelope>
# in:<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
# in:  <soapenv:Body>
# in:    <ns:executeSQLQueryResponse xmlns:ns="http://www.cisco.com/AXL/API/11.5">
# in:      <return>
# in:        <row>
# in:          <dnorpattern>\+19195551000</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551001</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551002</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551003</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551004</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551005</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551006</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551007</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551008</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551009</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551010</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551011</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551011</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551012</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551013</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551014</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551015</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551016</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551017</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551018</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551018</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551019</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551020</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551021</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551022</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551023</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551024</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551026</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551027</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551028</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551029</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551030</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551031</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551032</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551033</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551034</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551035</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551036</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551037</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551038</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551039</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551040</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551041</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551042</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551043</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551044</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551045</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551046</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551047</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551048</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551049</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551050</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551051</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551052</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551053</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551054</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551055</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551056</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551057</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551058</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551059</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551060</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551061</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551062</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551063</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551064</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551065</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551066</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551067</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551068</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551069</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551070</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551071</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551072</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551073</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551074</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551075</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551076</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551077</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551078</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551079</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551080</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551081</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551082</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551083</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551084</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551085</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551086</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551087</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551088</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551089</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551090</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551091</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551092</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551093</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551094</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551094</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551095</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551096</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551097</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551098</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551099</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551100</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551101</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551102</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551103</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551104</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551105</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551106</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551107</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551108</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551109</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551110</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551111</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551112</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551113</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551114</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551115</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551116</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551117</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551118</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551119</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551120</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551121</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551123</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551124</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551125</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551126</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551127</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551128</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551129</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551130</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551131</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551132</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551133</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551134</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551135</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551136</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551137</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551138</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551139</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551140</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551141</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551142</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551143</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551144</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551145</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551146</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551147</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551148</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551149</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551150</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551151</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551152</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551153</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551154</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551155</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551156</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551157</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551158</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551300</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551301</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551302</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551303</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551304</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551777</dnorpattern>
# in:          <tkpatternusage>2</tkpatternusage>
# in:        </row>
# in:      </return>
# in:    </ns:executeSQLQueryResponse>
# in:  </soapenv:Body>
# in:</soapenv:Envelope>

# %%
if r['return'] is None:
    print('No matching DNs found')
else:
    dns = [r[0].text for r in r['return'].row]
    print(dns)
# Out:
# ['\\+19195551000', '\\+19195551001', '\\+19195551002', '\\+19195551003', '\\+19195551004', '\\+19195551005', '\\+19195551006', '\\+19195551007', '\\+19195551008', '\\+19195551009', '\\+19195551010', '\\+19195551011', '\\+19195551011', '\\+19195551012', '\\+19195551013', '\\+19195551014', '\\+19195551015', '\\+19195551016', '\\+19195551017', '\\+19195551018', '\\+19195551018', '\\+19195551019', '\\+19195551020', '\\+19195551021', '\\+19195551022', '\\+19195551023', '\\+19195551024', '\\+19195551026', '\\+19195551027', '\\+19195551028', '\\+19195551029', '\\+19195551030', '\\+19195551031', '\\+19195551032', '\\+19195551033', '\\+19195551034', '\\+19195551035', '\\+19195551036', '\\+19195551037', '\\+19195551038', '\\+19195551039', '\\+19195551040', '\\+19195551041', '\\+19195551042', '\\+19195551043', '\\+19195551044', '\\+19195551045', '\\+19195551046', '\\+19195551047', '\\+19195551048', '\\+19195551049', '\\+19195551050', '\\+19195551051', '\\+19195551052', '\\+19195551053', '\\+19195551054', '\\+19195551055', '\\+19195551056', '\\+19195551057', '\\+19195551058', '\\+19195551059', '\\+19195551060', '\\+19195551061', '\\+19195551062', '\\+19195551063', '\\+19195551064', '\\+19195551065', '\\+19195551066', '\\+19195551067', '\\+19195551068', '\\+19195551069', '\\+19195551070', '\\+19195551071', '\\+19195551072', '\\+19195551073', '\\+19195551074', '\\+19195551075', '\\+19195551076', '\\+19195551077', '\\+19195551078', '\\+19195551079', '\\+19195551080', '\\+19195551081', '\\+19195551082', '\\+19195551083', '\\+19195551084', '\\+19195551085', '\\+19195551086', '\\+19195551087', '\\+19195551088', '\\+19195551089', '\\+19195551090', '\\+19195551091', '\\+19195551092', '\\+19195551093', '\\+19195551094', '\\+19195551094', '\\+19195551095', '\\+19195551096', '\\+19195551097', '\\+19195551098', '\\+19195551099', '\\+19195551100', '\\+19195551101', '\\+19195551102', '\\+19195551103', '\\+19195551104', '\\+19195551105', '\\+19195551106', '\\+19195551107', '\\+19195551108', '\\+19195551109', '\\+19195551110', '\\+19195551111', '\\+19195551112', '\\+19195551113', '\\+19195551114', '\\+19195551115', '\\+19195551116', '\\+19195551117', '\\+19195551118', '\\+19195551119', '\\+19195551120', '\\+19195551121', '\\+19195551123', '\\+19195551124', '\\+19195551125', '\\+19195551126', '\\+19195551127', '\\+19195551128', '\\+19195551129', '\\+19195551130', '\\+19195551131', '\\+19195551132', '\\+19195551133', '\\+19195551134', '\\+19195551135', '\\+19195551136', '\\+19195551137', '\\+19195551138', '\\+19195551139', '\\+19195551140', '\\+19195551141', '\\+19195551142', '\\+19195551143', '\\+19195551144', '\\+19195551145', '\\+19195551146', '\\+19195551147', '\\+19195551148', '\\+19195551149', '\\+19195551150', '\\+19195551151', '\\+19195551152', '\\+19195551153', '\\+19195551154', '\\+19195551155', '\\+19195551156', '\\+19195551157', '\\+19195551158', '\\+19195551300', '\\+19195551301', '\\+19195551302', '\\+19195551303', '\\+19195551304', '\\+19195551777']

# %% [markdown]
# Knowing the enum for DNs the above query obviously could also have been simplified to only using the numplan table .. and no join.

# %%
r = service.executeSQLQuery(('select dnorpattern from numplan '
                             'where tkpatternusage=2 and '
                             'dnorpattern like "%+1919%" '
                             'order by dnorpattern'))
# Out:
# out:<soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
# out:  <soap-env:Body>
# out:    <ns0:executeSQLQuery xmlns:ns0="http://www.cisco.com/AXL/API/11.5">
# out:      <sql>select dnorpattern from numplan where tkpatternusage=2 and dnorpattern like "%+1919%" order by dnorpattern</sql>
# out:    </ns0:executeSQLQuery>
# out:  </soap-env:Body>
# out:</soap-env:Envelope>
# in:<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
# in:  <soapenv:Body>
# in:    <ns:executeSQLQueryResponse xmlns:ns="http://www.cisco.com/AXL/API/11.5">
# in:      <return>
# in:        <row>
# in:          <dnorpattern>\+19195551000</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551001</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551002</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551003</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551004</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551005</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551006</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551007</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551008</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551009</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551010</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551011</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551011</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551012</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551013</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551014</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551015</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551016</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551017</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551018</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551018</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551019</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551020</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551021</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551022</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551023</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551024</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551026</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551027</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551028</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551029</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551030</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551031</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551032</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551033</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551034</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551035</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551036</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551037</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551038</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551039</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551040</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551041</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551042</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551043</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551044</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551045</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551046</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551047</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551048</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551049</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551050</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551051</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551052</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551053</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551054</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551055</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551056</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551057</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551058</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551059</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551060</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551061</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551062</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551063</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551064</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551065</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551066</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551067</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551068</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551069</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551070</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551071</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551072</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551073</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551074</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551075</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551076</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551077</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551078</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551079</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551080</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551081</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551082</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551083</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551084</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551085</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551086</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551087</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551088</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551089</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551090</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551091</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551092</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551093</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551094</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551094</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551095</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551096</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551097</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551098</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551099</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551100</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551101</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551102</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551103</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551104</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551105</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551106</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551107</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551108</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551109</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551110</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551111</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551112</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551113</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551114</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551115</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551116</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551117</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551118</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551119</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551120</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551121</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551123</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551124</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551125</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551126</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551127</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551128</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551129</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551130</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551131</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551132</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551133</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551134</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551135</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551136</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551137</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551138</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551139</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551140</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551141</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551142</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551143</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551144</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551145</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551146</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551147</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551148</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551149</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551150</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551151</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551152</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551153</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551154</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551155</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551156</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551157</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551158</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551300</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551301</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551302</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551303</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551304</dnorpattern>
# in:        </row>
# in:        <row>
# in:          <dnorpattern>\+19195551777</dnorpattern>
# in:        </row>
# in:      </return>
# in:    </ns:executeSQLQueryResponse>
# in:  </soapenv:Body>
# in:</soapenv:Envelope>

# %%
if r['return'] is None:
    print('No matching DNs found')
else:
    dns = [r[0].text for r in r['return'].row]
    print(dns)
# Out:
# ['\\+19195551000', '\\+19195551001', '\\+19195551002', '\\+19195551003', '\\+19195551004', '\\+19195551005', '\\+19195551006', '\\+19195551007', '\\+19195551008', '\\+19195551009', '\\+19195551010', '\\+19195551011', '\\+19195551011', '\\+19195551012', '\\+19195551013', '\\+19195551014', '\\+19195551015', '\\+19195551016', '\\+19195551017', '\\+19195551018', '\\+19195551018', '\\+19195551019', '\\+19195551020', '\\+19195551021', '\\+19195551022', '\\+19195551023', '\\+19195551024', '\\+19195551026', '\\+19195551027', '\\+19195551028', '\\+19195551029', '\\+19195551030', '\\+19195551031', '\\+19195551032', '\\+19195551033', '\\+19195551034', '\\+19195551035', '\\+19195551036', '\\+19195551037', '\\+19195551038', '\\+19195551039', '\\+19195551040', '\\+19195551041', '\\+19195551042', '\\+19195551043', '\\+19195551044', '\\+19195551045', '\\+19195551046', '\\+19195551047', '\\+19195551048', '\\+19195551049', '\\+19195551050', '\\+19195551051', '\\+19195551052', '\\+19195551053', '\\+19195551054', '\\+19195551055', '\\+19195551056', '\\+19195551057', '\\+19195551058', '\\+19195551059', '\\+19195551060', '\\+19195551061', '\\+19195551062', '\\+19195551063', '\\+19195551064', '\\+19195551065', '\\+19195551066', '\\+19195551067', '\\+19195551068', '\\+19195551069', '\\+19195551070', '\\+19195551071', '\\+19195551072', '\\+19195551073', '\\+19195551074', '\\+19195551075', '\\+19195551076', '\\+19195551077', '\\+19195551078', '\\+19195551079', '\\+19195551080', '\\+19195551081', '\\+19195551082', '\\+19195551083', '\\+19195551084', '\\+19195551085', '\\+19195551086', '\\+19195551087', '\\+19195551088', '\\+19195551089', '\\+19195551090', '\\+19195551091', '\\+19195551092', '\\+19195551093', '\\+19195551094', '\\+19195551094', '\\+19195551095', '\\+19195551096', '\\+19195551097', '\\+19195551098', '\\+19195551099', '\\+19195551100', '\\+19195551101', '\\+19195551102', '\\+19195551103', '\\+19195551104', '\\+19195551105', '\\+19195551106', '\\+19195551107', '\\+19195551108', '\\+19195551109', '\\+19195551110', '\\+19195551111', '\\+19195551112', '\\+19195551113', '\\+19195551114', '\\+19195551115', '\\+19195551116', '\\+19195551117', '\\+19195551118', '\\+19195551119', '\\+19195551120', '\\+19195551121', '\\+19195551123', '\\+19195551124', '\\+19195551125', '\\+19195551126', '\\+19195551127', '\\+19195551128', '\\+19195551129', '\\+19195551130', '\\+19195551131', '\\+19195551132', '\\+19195551133', '\\+19195551134', '\\+19195551135', '\\+19195551136', '\\+19195551137', '\\+19195551138', '\\+19195551139', '\\+19195551140', '\\+19195551141', '\\+19195551142', '\\+19195551143', '\\+19195551144', '\\+19195551145', '\\+19195551146', '\\+19195551147', '\\+19195551148', '\\+19195551149', '\\+19195551150', '\\+19195551151', '\\+19195551152', '\\+19195551153', '\\+19195551154', '\\+19195551155', '\\+19195551156', '\\+19195551157', '\\+19195551158', '\\+19195551300', '\\+19195551301', '\\+19195551302', '\\+19195551303', '\\+19195551304', '\\+19195551777']

# %% [markdown]
# ### Getting device counts per device type

# %%
r = service.executeSQLQuery(('select count(d.name) c, tm.name from device d '
                             'inner join typemodel tm on d.tkmodel=tm.enum '
                             'where tm.tkclass=1 '
                             'group by tm.name '
                             'order by tm.name'))
# Out:
# out:<soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
# out:  <soap-env:Body>
# out:    <ns0:executeSQLQuery xmlns:ns0="http://www.cisco.com/AXL/API/11.5">
# out:      <sql>select count(d.name) c, tm.name from device d inner join typemodel tm on d.tkmodel=tm.enum where tm.tkclass=1 group by tm.name order by tm.name</sql>
# out:    </ns0:executeSQLQuery>
# out:  </soap-env:Body>
# out:</soap-env:Envelope>
# in:<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
# in:  <soapenv:Body>
# in:    <ns:executeSQLQueryResponse xmlns:ns="http://www.cisco.com/AXL/API/11.5">
# in:      <return>
# in:        <row>
# in:          <c>11</c>
# in:          <name>CTI Port</name>
# in:        </row>
# in:        <row>
# in:          <c>34</c>
# in:          <name>CTI Remote Device</name>
# in:        </row>
# in:        <row>
# in:          <c>4</c>
# in:          <name>Cisco 7821</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <name>Cisco 7861</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <name>Cisco 7960</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <name>Cisco 7962</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <name>Cisco 7965</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <name>Cisco 7971</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <name>Cisco 7975</name>
# in:        </row>
# in:        <row>
# in:          <c>3</c>
# in:          <name>Cisco 8811</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <name>Cisco 8821</name>
# in:        </row>
# in:        <row>
# in:          <c>3</c>
# in:          <name>Cisco 8831</name>
# in:        </row>
# in:        <row>
# in:          <c>3</c>
# in:          <name>Cisco 8832</name>
# in:        </row>
# in:        <row>
# in:          <c>3</c>
# in:          <name>Cisco 8841</name>
# in:        </row>
# in:        <row>
# in:          <c>13</c>
# in:          <name>Cisco 8845</name>
# in:        </row>
# in:        <row>
# in:          <c>3</c>
# in:          <name>Cisco 8851</name>
# in:        </row>
# in:        <row>
# in:          <c>3</c>
# in:          <name>Cisco 8861</name>
# in:        </row>
# in:        <row>
# in:          <c>17</c>
# in:          <name>Cisco 8865</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <name>Cisco 8945</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <name>Cisco 8961</name>
# in:        </row>
# in:        <row>
# in:          <c>4</c>
# in:          <name>Cisco 9951</name>
# in:        </row>
# in:        <row>
# in:          <c>22</c>
# in:          <name>Cisco 9971</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <name>Cisco ATA 190</name>
# in:        </row>
# in:        <row>
# in:          <c>14</c>
# in:          <name>Cisco DX650</name>
# in:        </row>
# in:        <row>
# in:          <c>6</c>
# in:          <name>Cisco DX70</name>
# in:        </row>
# in:        <row>
# in:          <c>9</c>
# in:          <name>Cisco DX80</name>
# in:        </row>
# in:        <row>
# in:          <c>5</c>
# in:          <name>Cisco Dual Mode for Android</name>
# in:        </row>
# in:        <row>
# in:          <c>9</c>
# in:          <name>Cisco Dual Mode for iPhone</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <name>Cisco IP Communicator</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <name>Cisco Jabber for Tablet</name>
# in:        </row>
# in:        <row>
# in:          <c>457</c>
# in:          <name>Cisco Spark Remote Device</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <name>Cisco TelePresence Codec C40</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <name>Cisco TelePresence Codec C60</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <name>Cisco TelePresence Codec C90</name>
# in:        </row>
# in:        <row>
# in:          <c>8</c>
# in:          <name>Cisco TelePresence DX70</name>
# in:        </row>
# in:        <row>
# in:          <c>4</c>
# in:          <name>Cisco TelePresence EX60</name>
# in:        </row>
# in:        <row>
# in:          <c>5</c>
# in:          <name>Cisco TelePresence EX90</name>
# in:        </row>
# in:        <row>
# in:          <c>3</c>
# in:          <name>Cisco TelePresence IX5000</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <name>Cisco TelePresence MX200 G2</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <name>Cisco TelePresence MX300 G2</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <name>Cisco TelePresence MX700</name>
# in:        </row>
# in:        <row>
# in:          <c>9</c>
# in:          <name>Cisco TelePresence SX10</name>
# in:        </row>
# in:        <row>
# in:          <c>5</c>
# in:          <name>Cisco TelePresence SX20</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <name>Cisco TelePresence SX80</name>
# in:        </row>
# in:        <row>
# in:          <c>495</c>
# in:          <name>Cisco Unified Client Services Framework</name>
# in:        </row>
# in:        <row>
# in:          <c>8</c>
# in:          <name>Cisco Webex DX80</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <name>Cisco Webex Room Kit</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <name>Cisco Webex Room Kit Mini</name>
# in:        </row>
# in:        <row>
# in:          <c>5</c>
# in:          <name>Universal Device Template</name>
# in:        </row>
# in:      </return>
# in:    </ns:executeSQLQueryResponse>
# in:  </soapenv:Body>
# in:</soapenv:Envelope>

# %%
rows = [Row(r) for r in r['return'].row]
max_name = max(len(r.name) for r in rows)
print('\n'.join(f'{r.name:{max_name}} : {r.c}' for r in rows))
# Out:
# CTI Port                                : 11
# CTI Remote Device                       : 34
# Cisco 7821                              : 4
# Cisco 7861                              : 1
# Cisco 7960                              : 2
# Cisco 7962                              : 1
# Cisco 7965                              : 2
# Cisco 7971                              : 1
# Cisco 7975                              : 1
# Cisco 8811                              : 3
# Cisco 8821                              : 2
# Cisco 8831                              : 3
# Cisco 8832                              : 3
# Cisco 8841                              : 3
# Cisco 8845                              : 13
# Cisco 8851                              : 3
# Cisco 8861                              : 3
# Cisco 8865                              : 17
# Cisco 8945                              : 2
# Cisco 8961                              : 1
# Cisco 9951                              : 4
# Cisco 9971                              : 22
# Cisco ATA 190                           : 2
# Cisco DX650                             : 14
# Cisco DX70                              : 6
# Cisco DX80                              : 9
# Cisco Dual Mode for Android             : 5
# Cisco Dual Mode for iPhone              : 9
# Cisco IP Communicator                   : 1
# Cisco Jabber for Tablet                 : 1
# Cisco Spark Remote Device               : 457
# Cisco TelePresence Codec C40            : 2
# Cisco TelePresence Codec C60            : 1
# Cisco TelePresence Codec C90            : 1
# Cisco TelePresence DX70                 : 8
# Cisco TelePresence EX60                 : 4
# Cisco TelePresence EX90                 : 5
# Cisco TelePresence IX5000               : 3
# Cisco TelePresence MX200 G2             : 1
# Cisco TelePresence MX300 G2             : 1
# Cisco TelePresence MX700                : 1
# Cisco TelePresence SX10                 : 9
# Cisco TelePresence SX20                 : 5
# Cisco TelePresence SX80                 : 2
# Cisco Unified Client Services Framework : 495
# Cisco Webex DX80                        : 8
# Cisco Webex Room Kit                    : 2
# Cisco Webex Room Kit Mini               : 2
# Universal Device Template               : 5

# %% [markdown]
# ### Device counts per device pool and device type

# %%
r = service.executeSQLQuery(('select count(d.name) c, dp.name dpname, tm.name from device d '
                             'inner join typemodel tm on d.tkmodel=tm.enum '
                             'inner join devicepool dp on d.fkdevicepool=dp.pkid '
                             'where tm.tkclass=1 '
                             'group by dpname, tm.name '
                             'order by dpname, tm.name'))
# Out:
# out:<soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
# out:  <soap-env:Body>
# out:    <ns0:executeSQLQuery xmlns:ns0="http://www.cisco.com/AXL/API/11.5">
# out:      <sql>select count(d.name) c, dp.name dpname, tm.name from device d inner join typemodel tm on d.tkmodel=tm.enum inner join devicepool dp on d.fkdevicepool=dp.pkid where tm.tkclass=1 group by dpname, tm.name order by dpname, tm.name</sql>
# out:    </ns0:executeSQLQuery>
# out:  </soap-env:Body>
# out:</soap-env:Envelope>
# in:<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
# in:  <soapenv:Body>
# in:    <ns:executeSQLQueryResponse xmlns:ns="http://www.cisco.com/AXL/API/11.5">
# in:      <return>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>Default</dpname>
# in:          <name>CTI Remote Device</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>Default</dpname>
# in:          <name>Cisco 8811</name>
# in:        </row>
# in:        <row>
# in:          <c>3</c>
# in:          <dpname>Default</dpname>
# in:          <name>Cisco 8845</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>Default</dpname>
# in:          <name>Cisco DX650</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>Default</dpname>
# in:          <name>Cisco TelePresence DX70</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>Default</dpname>
# in:          <name>Universal Device Template</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RB1_Video_20MB</dpname>
# in:          <name>Cisco DX650</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RB1_Video_encryptedSRST_20MB</dpname>
# in:          <name>Cisco 7975</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>RB1_Video_encryptedSRST_20MB</dpname>
# in:          <name>Cisco 8865</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RB1_Video_encryptedSRST_20MB</dpname>
# in:          <name>Cisco 9971</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RB1_Video_encryptedSRST_20MB</dpname>
# in:          <name>Cisco DX650</name>
# in:        </row>
# in:        <row>
# in:          <c>5</c>
# in:          <dpname>RCD</dpname>
# in:          <name>CTI Remote Device</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RCD</dpname>
# in:          <name>Cisco 7861</name>
# in:        </row>
# in:        <row>
# in:          <c>3</c>
# in:          <dpname>RCD</dpname>
# in:          <name>Cisco 9971</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RCD</dpname>
# in:          <name>Cisco Dual Mode for Android</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RCD</dpname>
# in:          <name>Cisco Dual Mode for iPhone</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RCD</dpname>
# in:          <name>Cisco IP Communicator</name>
# in:        </row>
# in:        <row>
# in:          <c>159</c>
# in:          <dpname>RCD</dpname>
# in:          <name>Cisco Spark Remote Device</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RCD</dpname>
# in:          <name>Cisco TelePresence EX60</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RCD</dpname>
# in:          <name>Cisco TelePresence EX90</name>
# in:        </row>
# in:        <row>
# in:          <c>167</c>
# in:          <dpname>RCD</dpname>
# in:          <name>Cisco Unified Client Services Framework</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RCD</dpname>
# in:          <name>Cisco Webex DX80</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>RTP_Video_1.5MB</dpname>
# in:          <name>Cisco 8845</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_1.5MB</dpname>
# in:          <name>Cisco 8961</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_1.5MB</dpname>
# in:          <name>Cisco Unified Client Services Framework</name>
# in:        </row>
# in:        <row>
# in:          <c>8</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>CTI Remote Device</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco 8841</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco 8861</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco 8865</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco 9951</name>
# in:        </row>
# in:        <row>
# in:          <c>6</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco 9971</name>
# in:        </row>
# in:        <row>
# in:          <c>6</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco DX650</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco DX70</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco DX80</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco Dual Mode for Android</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco Dual Mode for iPhone</name>
# in:        </row>
# in:        <row>
# in:          <c>152</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco Spark Remote Device</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco TelePresence DX70</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco TelePresence SX10</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco TelePresence SX20</name>
# in:        </row>
# in:        <row>
# in:          <c>162</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Cisco Unified Client Services Framework</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_2.5MB</dpname>
# in:          <name>Universal Device Template</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>RTP_Video_20MB</dpname>
# in:          <name>Cisco 8865</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_20MB</dpname>
# in:          <name>Cisco DX70</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_20MB</dpname>
# in:          <name>Cisco Dual Mode for iPhone</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>RTP_Video_20MB</dpname>
# in:          <name>Cisco TelePresence IX5000</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_20MB</dpname>
# in:          <name>Cisco TelePresence MX300 G2</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_20MB</dpname>
# in:          <name>Cisco TelePresence SX10</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>RTP_Video_20MB</dpname>
# in:          <name>Cisco TelePresence SX20</name>
# in:        </row>
# in:        <row>
# in:          <c>4</c>
# in:          <dpname>RTP_Video_20MB</dpname>
# in:          <name>Cisco Webex DX80</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_1.5MB</dpname>
# in:          <name>Cisco 8845</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_1.5MB</dpname>
# in:          <name>Cisco 8865</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_1.5MB</dpname>
# in:          <name>Cisco Dual Mode for iPhone</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_1.5MB</dpname>
# in:          <name>Cisco Jabber for Tablet</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_1.5MB</dpname>
# in:          <name>Cisco TelePresence IX5000</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_1.5MB</dpname>
# in:          <name>Cisco Unified Client Services Framework</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_1.5MB_sub2asCallProcessing</dpname>
# in:          <name>Cisco TelePresence DX70</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>CTI Port</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>CTI Remote Device</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco 7821</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco 7965</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco 8821</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco 8831</name>
# in:        </row>
# in:        <row>
# in:          <c>4</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco 8845</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco 8851</name>
# in:        </row>
# in:        <row>
# in:          <c>4</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco 8865</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco 8945</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco 9971</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco DX650</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco DX70</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco DX80</name>
# in:        </row>
# in:        <row>
# in:          <c>4</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco Dual Mode for iPhone</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco Spark Remote Device</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco TelePresence DX70</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco TelePresence EX60</name>
# in:        </row>
# in:        <row>
# in:          <c>4</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco TelePresence SX10</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco TelePresence SX80</name>
# in:        </row>
# in:        <row>
# in:          <c>4</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco Unified Client Services Framework</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco Webex DX80</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>SJC_Video_2.5MB</dpname>
# in:          <name>Cisco Webex Room Kit</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-LPHAM-us-cm-pub</dpname>
# in:          <name>Cisco 8865</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-LPHAM-us-cm-pub</dpname>
# in:          <name>Universal Device Template</name>
# in:        </row>
# in:        <row>
# in:          <c>10</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>CTI Port</name>
# in:        </row>
# in:        <row>
# in:          <c>19</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>CTI Remote Device</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco 7821</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco 7960</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco 7965</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco 8811</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco 8832</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco 8841</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco 8845</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco 8851</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco 8861</name>
# in:        </row>
# in:        <row>
# in:          <c>5</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco 8865</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco 9951</name>
# in:        </row>
# in:        <row>
# in:          <c>8</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco 9971</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco ATA 190</name>
# in:        </row>
# in:        <row>
# in:          <c>3</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco DX650</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco DX70</name>
# in:        </row>
# in:        <row>
# in:          <c>6</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco DX80</name>
# in:        </row>
# in:        <row>
# in:          <c>3</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco Dual Mode for Android</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco Dual Mode for iPhone</name>
# in:        </row>
# in:        <row>
# in:          <c>144</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco Spark Remote Device</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco TelePresence Codec C40</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco TelePresence Codec C60</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco TelePresence Codec C90</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco TelePresence DX70</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco TelePresence EX60</name>
# in:        </row>
# in:        <row>
# in:          <c>3</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco TelePresence EX90</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco TelePresence MX200 G2</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco TelePresence MX700</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco TelePresence SX10</name>
# in:        </row>
# in:        <row>
# in:          <c>2</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco TelePresence SX20</name>
# in:        </row>
# in:        <row>
# in:          <c>160</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco Unified Client Services Framework</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco Webex DX80</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Cisco Webex Room Kit Mini</name>
# in:        </row>
# in:        <row>
# in:          <c>1</c>
# in:          <dpname>TEST-SJC_in_Default Region_with_Milan_Local_Time</dpname>
# in:          <name>Universal Device Template</name>
# in:        </row>
# in:      </return>
# in:    </ns:executeSQLQueryResponse>
# in:  </soapenv:Body>
# in:</soapenv:Envelope>

# %%
rows = [Row(r) for r in r['return'].row]
max_name = max(len(r.name) for r in rows)
max_dp = max(len(r.dpname) for r in rows)
print('\n'.join(f'{r.dpname:{max_dp}}/{r.name:{max_name}} : {r.c}' for r in rows))
# Out:
# Default                                         /CTI Remote Device                       : 1
# Default                                         /Cisco 8811                              : 1
# Default                                         /Cisco 8845                              : 3
# Default                                         /Cisco DX650                             : 1
# Default                                         /Cisco TelePresence DX70                 : 1
# Default                                         /Universal Device Template               : 2
# RB1_Video_20MB                                  /Cisco DX650                             : 1
# RB1_Video_encryptedSRST_20MB                    /Cisco 7975                              : 1
# RB1_Video_encryptedSRST_20MB                    /Cisco 8865                              : 2
# RB1_Video_encryptedSRST_20MB                    /Cisco 9971                              : 1
# RB1_Video_encryptedSRST_20MB                    /Cisco DX650                             : 1
# RCD                                             /CTI Remote Device                       : 5
# RCD                                             /Cisco 7861                              : 1
# RCD                                             /Cisco 9971                              : 3
# RCD                                             /Cisco Dual Mode for Android             : 1
# RCD                                             /Cisco Dual Mode for iPhone              : 1
# RCD                                             /Cisco IP Communicator                   : 1
# RCD                                             /Cisco Spark Remote Device               : 159
# RCD                                             /Cisco TelePresence EX60                 : 1
# RCD                                             /Cisco TelePresence EX90                 : 1
# RCD                                             /Cisco Unified Client Services Framework : 167
# RCD                                             /Cisco Webex DX80                        : 1
# RTP_Video_1.5MB                                 /Cisco 8845                              : 2
# RTP_Video_1.5MB                                 /Cisco 8961                              : 1
# RTP_Video_1.5MB                                 /Cisco Unified Client Services Framework : 1
# RTP_Video_2.5MB                                 /CTI Remote Device                       : 8
# RTP_Video_2.5MB                                 /Cisco 8841                              : 1
# RTP_Video_2.5MB                                 /Cisco 8861                              : 2
# RTP_Video_2.5MB                                 /Cisco 8865                              : 1
# RTP_Video_2.5MB                                 /Cisco 9951                              : 2
# RTP_Video_2.5MB                                 /Cisco 9971                              : 6
# RTP_Video_2.5MB                                 /Cisco DX650                             : 6
# RTP_Video_2.5MB                                 /Cisco DX70                              : 1
# RTP_Video_2.5MB                                 /Cisco DX80                              : 1
# RTP_Video_2.5MB                                 /Cisco Dual Mode for Android             : 1
# RTP_Video_2.5MB                                 /Cisco Dual Mode for iPhone              : 1
# RTP_Video_2.5MB                                 /Cisco Spark Remote Device               : 152
# RTP_Video_2.5MB                                 /Cisco TelePresence DX70                 : 1
# RTP_Video_2.5MB                                 /Cisco TelePresence SX10                 : 2
# RTP_Video_2.5MB                                 /Cisco TelePresence SX20                 : 1
# RTP_Video_2.5MB                                 /Cisco Unified Client Services Framework : 162
# RTP_Video_2.5MB                                 /Universal Device Template               : 1
# RTP_Video_20MB                                  /Cisco 8865                              : 2
# RTP_Video_20MB                                  /Cisco DX70                              : 1
# RTP_Video_20MB                                  /Cisco Dual Mode for iPhone              : 1
# RTP_Video_20MB                                  /Cisco TelePresence IX5000               : 2
# RTP_Video_20MB                                  /Cisco TelePresence MX300 G2             : 1
# RTP_Video_20MB                                  /Cisco TelePresence SX10                 : 1
# RTP_Video_20MB                                  /Cisco TelePresence SX20                 : 1
# RTP_Video_20MB                                  /Cisco Webex DX80                        : 4
# SJC_Video_1.5MB                                 /Cisco 8845                              : 1
# SJC_Video_1.5MB                                 /Cisco 8865                              : 1
# SJC_Video_1.5MB                                 /Cisco Dual Mode for iPhone              : 1
# SJC_Video_1.5MB                                 /Cisco Jabber for Tablet                 : 1
# SJC_Video_1.5MB                                 /Cisco TelePresence IX5000               : 1
# SJC_Video_1.5MB                                 /Cisco Unified Client Services Framework : 1
# SJC_Video_1.5MB_sub2asCallProcessing            /Cisco TelePresence DX70                 : 1
# SJC_Video_2.5MB                                 /CTI Port                                : 1
# SJC_Video_2.5MB                                 /CTI Remote Device                       : 1
# SJC_Video_2.5MB                                 /Cisco 7821                              : 1
# SJC_Video_2.5MB                                 /Cisco 7965                              : 1
# SJC_Video_2.5MB                                 /Cisco 8821                              : 1
# SJC_Video_2.5MB                                 /Cisco 8831                              : 2
# SJC_Video_2.5MB                                 /Cisco 8845                              : 4
# SJC_Video_2.5MB                                 /Cisco 8851                              : 2
# SJC_Video_2.5MB                                 /Cisco 8865                              : 4
# SJC_Video_2.5MB                                 /Cisco 8945                              : 1
# SJC_Video_2.5MB                                 /Cisco 9971                              : 2
# SJC_Video_2.5MB                                 /Cisco DX650                             : 1
# SJC_Video_2.5MB                                 /Cisco DX70                              : 1
# SJC_Video_2.5MB                                 /Cisco DX80                              : 1
# SJC_Video_2.5MB                                 /Cisco Dual Mode for iPhone              : 4
# SJC_Video_2.5MB                                 /Cisco Spark Remote Device               : 2
# SJC_Video_2.5MB                                 /Cisco TelePresence DX70                 : 2
# SJC_Video_2.5MB                                 /Cisco TelePresence EX60                 : 1
# SJC_Video_2.5MB                                 /Cisco TelePresence SX10                 : 4
# SJC_Video_2.5MB                                 /Cisco TelePresence SX80                 : 1
# SJC_Video_2.5MB                                 /Cisco Unified Client Services Framework : 4
# SJC_Video_2.5MB                                 /Cisco Webex DX80                        : 1
# SJC_Video_2.5MB                                 /Cisco Webex Room Kit                    : 1
# TEST-LPHAM-us-cm-pub                            /Cisco 8865                              : 1
# TEST-LPHAM-us-cm-pub                            /Universal Device Template               : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/CTI Port                                : 10
# TEST-SJC_in_Default Region_with_Milan_Local_Time/CTI Remote Device                       : 19
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco 7821                              : 2
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco 7960                              : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco 7965                              : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco 8811                              : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco 8832                              : 2
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco 8841                              : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco 8845                              : 2
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco 8851                              : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco 8861                              : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco 8865                              : 5
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco 9951                              : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco 9971                              : 8
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco ATA 190                           : 2
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco DX650                             : 3
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco DX70                              : 2
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco DX80                              : 6
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco Dual Mode for Android             : 3
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco Dual Mode for iPhone              : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco Spark Remote Device               : 144
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco TelePresence Codec C40            : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco TelePresence Codec C60            : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco TelePresence Codec C90            : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco TelePresence DX70                 : 2
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco TelePresence EX60                 : 2
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco TelePresence EX90                 : 3
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco TelePresence MX200 G2             : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco TelePresence MX700                : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco TelePresence SX10                 : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco TelePresence SX20                 : 2
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco Unified Client Services Framework : 160
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco Webex DX80                        : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Cisco Webex Room Kit Mini               : 1
# TEST-SJC_in_Default Region_with_Milan_Local_Time/Universal Device Template               : 1

# %% [markdown]
# ### More SQL Queries
#
# More examples can be found here: https://www.cisco.com/c/en/us/support/docs/unified-communications/unified-communications-manager-callmanager/117726-technote-cucm-00.html

# %% [markdown]
# # Adding Users

# %%
# list some users
r = service.listUser(searchCriteria={'lastName':'%'}, returnedTags={'userid':''}, first=10)
user_list = r['return'].user
print(user_list)
# Out:
# out:<soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
# out:  <soap-env:Body>
# out:    <ns0:listUser xmlns:ns0="http://www.cisco.com/AXL/API/11.5">
# out:      <searchCriteria>
# out:        <lastName>%</lastName>
# out:      </searchCriteria>
# out:      <returnedTags>
# out:        <userid></userid>
# out:      </returnedTags>
# out:      <first>10</first>
# out:    </ns0:listUser>
# out:  </soap-env:Body>
# out:</soap-env:Envelope>
# in:<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
# in:  <soapenv:Body>
# in:    <ns:listUserResponse xmlns:ns="http://www.cisco.com/AXL/API/11.5">
# in:      <return>
# in:        <user uuid="{01159FCB-206F-3E99-331D-1E912AE45D8B}">
# in:          <userid>nwheeler</userid>
# in:        </user>
# in:        <user uuid="{0137B722-B4BD-4926-E4E8-D4A8A12B413E}">
# in:          <userid>nmcdonal</userid>
# in:        </user>
# in:        <user uuid="{013F34E9-D7AE-6FFD-D60A-755405FCD9DF}">
# in:          <userid>bharrell</userid>
# in:        </user>
# in:        <user uuid="{014B41CE-0B94-B76C-DCFC-2F6566DF1D60}">
# in:          <userid>gnepero</userid>
# in:        </user>
# in:        <user uuid="{0180484E-9F89-90C0-1201-DEE7BBEC3AA1}">
# in:          <userid>vmclaugh</userid>
# in:        </user>
# in:        <user uuid="{01A6A4E2-D7B0-8FAC-03E6-527A961D11A1}">
# in:          <userid>jsandova</userid>
# in:        </user>
# in:        <user uuid="{01D197AA-0D3B-0EF2-F65C-030ACF9D33B8}">
# in:          <userid>dworkman</userid>
# in:        </user>
# in:        <user uuid="{020C45DE-BBB0-8AEE-C503-9FA33DBFDD37}">
# in:          <userid>jjohnson</userid>
# in:        </user>
# in:        <user uuid="{022DE390-6469-C3CE-80DA-5BF5BC46425C}">
# in:          <userid>fhyde</userid>
# in:        </user>
# in:        <user uuid="{024ECC78-987C-0413-ECB0-F2FFBD05D76A}">
# in:          <userid>hpace</userid>
# in:        </user>
# in:      </return>
# in:    </ns:listUserResponse>
# in:  </soapenv:Body>
# in:</soapenv:Envelope>
# [{
#     'firstName': None,
#     'displayName': None,
#     'middleName': None,
#     'lastName': None,
#     'userid': 'nwheeler',
#     'mailid': None,
#     'department': None,
#     'manager': None,
#     'userLocale': None,
#     'primaryExtension': None,
#     'associatedPc': None,
#     'enableCti': None,
#     'presenceGroupName': None,
#     'subscribeCallingSearchSpaceName': None,
#     'enableMobility': None,
#     'enableMobileVoiceAccess': None,
#     'maxDeskPickupWaitTime': None,
#     'remoteDestinationLimit': None,
#     'status': None,
#     'enableEmcc': None,
#     'patternPrecedence': None,
#     'numericUserId': None,
#     'mlppPassword': None,
#     'homeCluster': None,
#     'imAndPresenceEnable': None,
#     'serviceProfile': None,
#     'directoryUri': None,
#     'telephoneNumber': None,
#     'title': None,
#     'mobileNumber': None,
#     'homeNumber': None,
#     'pagerNumber': None,
#     'selfService': None,
#     'calendarPresence': None,
#     'ldapDirectoryName': None,
#     'userIdentity': None,
#     'accountType': None,
#     'authenticationType': None,
#     'enableUserToHostConferenceNow': None,
#     'attendeesAccessCode': None,
#     'uuid': '{01159FCB-206F-3E99-331D-1E912AE45D8B}'
# }, {
#     'firstName': None,
#     'displayName': None,
#     'middleName': None,
#     'lastName': None,
#     'userid': 'nmcdonal',
#     'mailid': None,
#     'department': None,
#     'manager': None,
#     'userLocale': None,
#     'primaryExtension': None,
#     'associatedPc': None,
#     'enableCti': None,
#     'presenceGroupName': None,
#     'subscribeCallingSearchSpaceName': None,
#     'enableMobility': None,
#     'enableMobileVoiceAccess': None,
#     'maxDeskPickupWaitTime': None,
#     'remoteDestinationLimit': None,
#     'status': None,
#     'enableEmcc': None,
#     'patternPrecedence': None,
#     'numericUserId': None,
#     'mlppPassword': None,
#     'homeCluster': None,
#     'imAndPresenceEnable': None,
#     'serviceProfile': None,
#     'directoryUri': None,
#     'telephoneNumber': None,
#     'title': None,
#     'mobileNumber': None,
#     'homeNumber': None,
#     'pagerNumber': None,
#     'selfService': None,
#     'calendarPresence': None,
#     'ldapDirectoryName': None,
#     'userIdentity': None,
#     'accountType': None,
#     'authenticationType': None,
#     'enableUserToHostConferenceNow': None,
#     'attendeesAccessCode': None,
#     'uuid': '{0137B722-B4BD-4926-E4E8-D4A8A12B413E}'
# }, {
#     'firstName': None,
#     'displayName': None,
#     'middleName': None,
#     'lastName': None,
#     'userid': 'bharrell',
#     'mailid': None,
#     'department': None,
#     'manager': None,
#     'userLocale': None,
#     'primaryExtension': None,
#     'associatedPc': None,
#     'enableCti': None,
#     'presenceGroupName': None,
#     'subscribeCallingSearchSpaceName': None,
#     'enableMobility': None,
#     'enableMobileVoiceAccess': None,
#     'maxDeskPickupWaitTime': None,
#     'remoteDestinationLimit': None,
#     'status': None,
#     'enableEmcc': None,
#     'patternPrecedence': None,
#     'numericUserId': None,
#     'mlppPassword': None,
#     'homeCluster': None,
#     'imAndPresenceEnable': None,
#     'serviceProfile': None,
#     'directoryUri': None,
#     'telephoneNumber': None,
#     'title': None,
#     'mobileNumber': None,
#     'homeNumber': None,
#     'pagerNumber': None,
#     'selfService': None,
#     'calendarPresence': None,
#     'ldapDirectoryName': None,
#     'userIdentity': None,
#     'accountType': None,
#     'authenticationType': None,
#     'enableUserToHostConferenceNow': None,
#     'attendeesAccessCode': None,
#     'uuid': '{013F34E9-D7AE-6FFD-D60A-755405FCD9DF}'
# }, {
#     'firstName': None,
#     'displayName': None,
#     'middleName': None,
#     'lastName': None,
#     'userid': 'gnepero',
#     'mailid': None,
#     'department': None,
#     'manager': None,
#     'userLocale': None,
#     'primaryExtension': None,
#     'associatedPc': None,
#     'enableCti': None,
#     'presenceGroupName': None,
#     'subscribeCallingSearchSpaceName': None,
#     'enableMobility': None,
#     'enableMobileVoiceAccess': None,
#     'maxDeskPickupWaitTime': None,
#     'remoteDestinationLimit': None,
#     'status': None,
#     'enableEmcc': None,
#     'patternPrecedence': None,
#     'numericUserId': None,
#     'mlppPassword': None,
#     'homeCluster': None,
#     'imAndPresenceEnable': None,
#     'serviceProfile': None,
#     'directoryUri': None,
#     'telephoneNumber': None,
#     'title': None,
#     'mobileNumber': None,
#     'homeNumber': None,
#     'pagerNumber': None,
#     'selfService': None,
#     'calendarPresence': None,
#     'ldapDirectoryName': None,
#     'userIdentity': None,
#     'accountType': None,
#     'authenticationType': None,
#     'enableUserToHostConferenceNow': None,
#     'attendeesAccessCode': None,
#     'uuid': '{014B41CE-0B94-B76C-DCFC-2F6566DF1D60}'
# }, {
#     'firstName': None,
#     'displayName': None,
#     'middleName': None,
#     'lastName': None,
#     'userid': 'vmclaugh',
#     'mailid': None,
#     'department': None,
#     'manager': None,
#     'userLocale': None,
#     'primaryExtension': None,
#     'associatedPc': None,
#     'enableCti': None,
#     'presenceGroupName': None,
#     'subscribeCallingSearchSpaceName': None,
#     'enableMobility': None,
#     'enableMobileVoiceAccess': None,
#     'maxDeskPickupWaitTime': None,
#     'remoteDestinationLimit': None,
#     'status': None,
#     'enableEmcc': None,
#     'patternPrecedence': None,
#     'numericUserId': None,
#     'mlppPassword': None,
#     'homeCluster': None,
#     'imAndPresenceEnable': None,
#     'serviceProfile': None,
#     'directoryUri': None,
#     'telephoneNumber': None,
#     'title': None,
#     'mobileNumber': None,
#     'homeNumber': None,
#     'pagerNumber': None,
#     'selfService': None,
#     'calendarPresence': None,
#     'ldapDirectoryName': None,
#     'userIdentity': None,
#     'accountType': None,
#     'authenticationType': None,
#     'enableUserToHostConferenceNow': None,
#     'attendeesAccessCode': None,
#     'uuid': '{0180484E-9F89-90C0-1201-DEE7BBEC3AA1}'
# }, {
#     'firstName': None,
#     'displayName': None,
#     'middleName': None,
#     'lastName': None,
#     'userid': 'jsandova',
#     'mailid': None,
#     'department': None,
#     'manager': None,
#     'userLocale': None,
#     'primaryExtension': None,
#     'associatedPc': None,
#     'enableCti': None,
#     'presenceGroupName': None,
#     'subscribeCallingSearchSpaceName': None,
#     'enableMobility': None,
#     'enableMobileVoiceAccess': None,
#     'maxDeskPickupWaitTime': None,
#     'remoteDestinationLimit': None,
#     'status': None,
#     'enableEmcc': None,
#     'patternPrecedence': None,
#     'numericUserId': None,
#     'mlppPassword': None,
#     'homeCluster': None,
#     'imAndPresenceEnable': None,
#     'serviceProfile': None,
#     'directoryUri': None,
#     'telephoneNumber': None,
#     'title': None,
#     'mobileNumber': None,
#     'homeNumber': None,
#     'pagerNumber': None,
#     'selfService': None,
#     'calendarPresence': None,
#     'ldapDirectoryName': None,
#     'userIdentity': None,
#     'accountType': None,
#     'authenticationType': None,
#     'enableUserToHostConferenceNow': None,
#     'attendeesAccessCode': None,
#     'uuid': '{01A6A4E2-D7B0-8FAC-03E6-527A961D11A1}'
# }, {
#     'firstName': None,
#     'displayName': None,
#     'middleName': None,
#     'lastName': None,
#     'userid': 'dworkman',
#     'mailid': None,
#     'department': None,
#     'manager': None,
#     'userLocale': None,
#     'primaryExtension': None,
#     'associatedPc': None,
#     'enableCti': None,
#     'presenceGroupName': None,
#     'subscribeCallingSearchSpaceName': None,
#     'enableMobility': None,
#     'enableMobileVoiceAccess': None,
#     'maxDeskPickupWaitTime': None,
#     'remoteDestinationLimit': None,
#     'status': None,
#     'enableEmcc': None,
#     'patternPrecedence': None,
#     'numericUserId': None,
#     'mlppPassword': None,
#     'homeCluster': None,
#     'imAndPresenceEnable': None,
#     'serviceProfile': None,
#     'directoryUri': None,
#     'telephoneNumber': None,
#     'title': None,
#     'mobileNumber': None,
#     'homeNumber': None,
#     'pagerNumber': None,
#     'selfService': None,
#     'calendarPresence': None,
#     'ldapDirectoryName': None,
#     'userIdentity': None,
#     'accountType': None,
#     'authenticationType': None,
#     'enableUserToHostConferenceNow': None,
#     'attendeesAccessCode': None,
#     'uuid': '{01D197AA-0D3B-0EF2-F65C-030ACF9D33B8}'
# }, {
#     'firstName': None,
#     'displayName': None,
#     'middleName': None,
#     'lastName': None,
#     'userid': 'jjohnson',
#     'mailid': None,
#     'department': None,
#     'manager': None,
#     'userLocale': None,
#     'primaryExtension': None,
#     'associatedPc': None,
#     'enableCti': None,
#     'presenceGroupName': None,
#     'subscribeCallingSearchSpaceName': None,
#     'enableMobility': None,
#     'enableMobileVoiceAccess': None,
#     'maxDeskPickupWaitTime': None,
#     'remoteDestinationLimit': None,
#     'status': None,
#     'enableEmcc': None,
#     'patternPrecedence': None,
#     'numericUserId': None,
#     'mlppPassword': None,
#     'homeCluster': None,
#     'imAndPresenceEnable': None,
#     'serviceProfile': None,
#     'directoryUri': None,
#     'telephoneNumber': None,
#     'title': None,
#     'mobileNumber': None,
#     'homeNumber': None,
#     'pagerNumber': None,
#     'selfService': None,
#     'calendarPresence': None,
#     'ldapDirectoryName': None,
#     'userIdentity': None,
#     'accountType': None,
#     'authenticationType': None,
#     'enableUserToHostConferenceNow': None,
#     'attendeesAccessCode': None,
#     'uuid': '{020C45DE-BBB0-8AEE-C503-9FA33DBFDD37}'
# }, {
#     'firstName': None,
#     'displayName': None,
#     'middleName': None,
#     'lastName': None,
#     'userid': 'fhyde',
#     'mailid': None,
#     'department': None,
#     'manager': None,
#     'userLocale': None,
#     'primaryExtension': None,
#     'associatedPc': None,
#     'enableCti': None,
#     'presenceGroupName': None,
#     'subscribeCallingSearchSpaceName': None,
#     'enableMobility': None,
#     'enableMobileVoiceAccess': None,
#     'maxDeskPickupWaitTime': None,
#     'remoteDestinationLimit': None,
#     'status': None,
#     'enableEmcc': None,
#     'patternPrecedence': None,
#     'numericUserId': None,
#     'mlppPassword': None,
#     'homeCluster': None,
#     'imAndPresenceEnable': None,
#     'serviceProfile': None,
#     'directoryUri': None,
#     'telephoneNumber': None,
#     'title': None,
#     'mobileNumber': None,
#     'homeNumber': None,
#     'pagerNumber': None,
#     'selfService': None,
#     'calendarPresence': None,
#     'ldapDirectoryName': None,
#     'userIdentity': None,
#     'accountType': None,
#     'authenticationType': None,
#     'enableUserToHostConferenceNow': None,
#     'attendeesAccessCode': None,
#     'uuid': '{022DE390-6469-C3CE-80DA-5BF5BC46425C}'
# }, {
#     'firstName': None,
#     'displayName': None,
#     'middleName': None,
#     'lastName': None,
#     'userid': 'hpace',
#     'mailid': None,
#     'department': None,
#     'manager': None,
#     'userLocale': None,
#     'primaryExtension': None,
#     'associatedPc': None,
#     'enableCti': None,
#     'presenceGroupName': None,
#     'subscribeCallingSearchSpaceName': None,
#     'enableMobility': None,
#     'enableMobileVoiceAccess': None,
#     'maxDeskPickupWaitTime': None,
#     'remoteDestinationLimit': None,
#     'status': None,
#     'enableEmcc': None,
#     'patternPrecedence': None,
#     'numericUserId': None,
#     'mlppPassword': None,
#     'homeCluster': None,
#     'imAndPresenceEnable': None,
#     'serviceProfile': None,
#     'directoryUri': None,
#     'telephoneNumber': None,
#     'title': None,
#     'mobileNumber': None,
#     'homeNumber': None,
#     'pagerNumber': None,
#     'selfService': None,
#     'calendarPresence': None,
#     'ldapDirectoryName': None,
#     'userIdentity': None,
#     'accountType': None,
#     'authenticationType': None,
#     'enableUserToHostConferenceNow': None,
#     'attendeesAccessCode': None,
#     'uuid': '{024ECC78-987C-0413-ECB0-F2FFBD05D76A}'
# }]

# %%
# get details of 1st user
user = user_list[0]
rt = 'firstName lastName userid presenceGroupName'
r = service.getUser(uuid=user.uuid, returnedTags={t:'' for t in rt.split()})
user_details = r['return'].user
print('\n'.join(f'{t}={user_details[t]}' for t in rt.split()))
# Out:
# out:<soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
# out:  <soap-env:Body>
# out:    <ns0:getUser xmlns:ns0="http://www.cisco.com/AXL/API/11.5">
# out:      <uuid>{01159FCB-206F-3E99-331D-1E912AE45D8B}</uuid>
# out:      <returnedTags>
# out:        <firstName></firstName>
# out:        <lastName></lastName>
# out:        <userid></userid>
# out:        <presenceGroupName></presenceGroupName>
# out:      </returnedTags>
# out:    </ns0:getUser>
# out:  </soap-env:Body>
# out:</soap-env:Envelope>
# in:<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
# in:  <soapenv:Body>
# in:    <ns:getUserResponse xmlns:ns="http://www.cisco.com/AXL/API/11.5">
# in:      <return>
# in:        <user uuid="{01159FCB-206F-3E99-331D-1E912AE45D8B}">
# in:          <firstName>Naomi</firstName>
# in:          <displayName>Naomi Wheeler</displayName>
# in:          <lastName>Wheeler</lastName>
# in:          <userid>nwheeler</userid>
# in:          <presenceGroupName uuid="{AD243D17-98B4-4118-8FEB-5FF2E1B781AC}">Standard Presence group</presenceGroupName>
# in:        </user>
# in:      </return>
# in:    </ns:getUserResponse>
# in:  </soapenv:Body>
# in:</soapenv:Envelope>
# firstName=Naomi
# lastName=Wheeler
# userid=nwheeler
# presenceGroupName={
#     '_value_1': 'Standard Presence group',
#     'uuid': '{AD243D17-98B4-4118-8FEB-5FF2E1B781AC}'
# }

# %%
# create a user object based on the type definition in the WSDL
factory = client.type_factory('ns0')
new_user = factory.XUser(
    firstName='Bob',
    lastName='Barnaby',
    userid='bbarnaby',
    presenceGroupName='Standard Presence group',
    # associated groups is a list of userGroup elements. Each userGroup has a name
    associatedGroups={
        'userGroup': [
            {'name': 'Standard CCM End Users'},
            {'name': 'Standard CTI Enabled'}
        ]
    }
)

# %% [markdown]
# Now try to add the user using the [addUser](https://pubhub.devnetcloud.com/media/axl-schema-reference/docs/Files/AXLSoap_AddUserReq.html#Link1EB) method

# %%
r = service.addUser(user=new_user)
# Out:
# out:<soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
# out:  <soap-env:Body>
# out:    <ns0:addUser xmlns:ns0="http://www.cisco.com/AXL/API/11.5">
# out:      <user>
# out:        <firstName>Bob</firstName>
# out:        <lastName>Barnaby</lastName>
# out:        <userid>bbarnaby</userid>
# out:        <associatedGroups>
# out:          <userGroup>
# out:            <name>Standard CCM End Users</name>
# out:          </userGroup>
# out:          <userGroup>
# out:            <name>Standard CTI Enabled</name>
# out:          </userGroup>
# out:        </associatedGroups>
# out:        <presenceGroupName>Standard Presence group</presenceGroupName>
# out:      </user>
# out:    </ns0:addUser>
# out:  </soap-env:Body>
# out:</soap-env:Envelope>
# in:<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
# in:  <soapenv:Body>
# in:    <ns:addUserResponse xmlns:ns="http://www.cisco.com/AXL/API/11.5">
# in:      <return>{376A38CD-BC4C-A698-BF25-D2D621494E6F}</return>
# in:    </ns:addUserResponse>
# in:  </soapenv:Body>
# in:</soapenv:Envelope>

# %%
new_user_uuid=r['return']
new_user_uuid
# Out:
# '{376A38CD-BC4C-A698-BF25-D2D621494E6F}'

# %% [markdown]
# We successfully added a user using AXL. Verify the success by checking the endusers on UCM.

# %% [markdown]
# # AXL Errors
#
# Let's try to add the same(!) user again and see what happens...

# %%
r = service.addUser(user=new_user)
# Out:
# out:<soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
# out:  <soap-env:Body>
# out:    <ns0:addUser xmlns:ns0="http://www.cisco.com/AXL/API/11.5">
# out:      <user>
# out:        <firstName>Bob</firstName>
# out:        <lastName>Barnaby</lastName>
# out:        <userid>bbarnaby</userid>
# out:        <associatedGroups>
# out:          <userGroup>
# out:            <name>Standard CCM End Users</name>
# out:          </userGroup>
# out:          <userGroup>
# out:            <name>Standard CTI Enabled</name>
# out:          </userGroup>
# out:        </associatedGroups>
# out:        <presenceGroupName>Standard Presence group</presenceGroupName>
# out:      </user>
# out:    </ns0:addUser>
# out:  </soap-env:Body>
# out:</soap-env:Envelope>
# in:<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
# in:  <soapenv:Body>
# in:    <soapenv:Fault>
# in:      <faultcode>soapenv:Client</faultcode>
# in:      <faultstring>Could not insert new row - duplicate value in a UNIQUE INDEX column (Unique Index:).</faultstring>
# in:      <detail>
# in:        <axlError>
# in:          <axlcode>-239</axlcode>
# in:          <axlmessage>Could not insert new row - duplicate value in a UNIQUE INDEX column (Unique Index:).</axlmessage>
# in:          <request>addUser</request>
# in:        </axlError>
# in:      </detail>
# in:    </soapenv:Fault>
# in:  </soapenv:Body>
# in:</soapenv:Envelope>
# ---------------------------------------------------------------------------
# Fault                                     Traceback (most recent call last)
# <ipython-input-35-9dc1f85eeb2d> in <module>
# ----> 1 r = service.addUser(user=new_user)
#
# ~/virtualenv/axlworkshop/lib/python3.7/site-packages/zeep/proxy.py in __call__(self, *args, **kwargs)
#      40         return self._proxy._binding.send(
#      41             self._proxy._client, self._proxy._binding_options,
# ---> 42             self._op_name, args, kwargs)
#      43
#      44
#
# ~/virtualenv/axlworkshop/lib/python3.7/site-packages/zeep/wsdl/bindings/soap.py in send(self, client, options, operation, args, kwargs)
#     130             return response
#     131
# --> 132         return self.process_reply(client, operation_obj, response)
#     133
#     134     def process_reply(self, client, operation, response):
#
# ~/virtualenv/axlworkshop/lib/python3.7/site-packages/zeep/wsdl/bindings/soap.py in process_reply(self, client, operation, response)
#     192             'soap-env:Body/soap-env:Fault', namespaces=self.nsmap)
#     193         if response.status_code != 200 or fault_node is not None:
# --> 194             return self.process_error(doc, operation)
#     195
#     196         result = operation.process_reply(doc)
#
# ~/virtualenv/axlworkshop/lib/python3.7/site-packages/zeep/wsdl/bindings/soap.py in process_error(self, doc, operation)
#     297             code=get_text('faultcode'),
#     298             actor=get_text('faultactor'),
# --> 299             detail=fault_node.find('detail'))
#     300
#     301     def _set_http_headers(self, serialized, operation):
#
# Fault: Could not insert new row - duplicate value in a UNIQUE INDEX column (Unique Index:).

# %% [markdown]
# The SOAP response clearly shows that the same user can not be added twice. Zeep raised an exception after receiving the soapenv:Fault.
#
# Python allows us to intercept exceptions and gracefully act on them

# %%
try:
    r = service.addUser(user=new_user)
except zeep.exceptions.Fault as fault:
    # catch zeep exception. The Fault object has the AXL errors message and the detail element
    # from which we can extract the integer AXL error code
    axl_code = int(fault.detail.find('.//axlcode').text)
    print(f"Failed to insert user: {axl_code}/{fault.message}")
else:
    print(f'Successfully added user. UUID: {r["return"]}')
# Out:
# out:<soap-env:Envelope xmlns:soap-env="http://schemas.xmlsoap.org/soap/envelope/">
# out:  <soap-env:Body>
# out:    <ns0:addUser xmlns:ns0="http://www.cisco.com/AXL/API/11.5">
# out:      <user>
# out:        <firstName>Bob</firstName>
# out:        <lastName>Barnaby</lastName>
# out:        <userid>bbarnaby</userid>
# out:        <associatedGroups>
# out:          <userGroup>
# out:            <name>Standard CCM End Users</name>
# out:          </userGroup>
# out:          <userGroup>
# out:            <name>Standard CTI Enabled</name>
# out:          </userGroup>
# out:        </associatedGroups>
# out:        <presenceGroupName>Standard Presence group</presenceGroupName>
# out:      </user>
# out:    </ns0:addUser>
# out:  </soap-env:Body>
# out:</soap-env:Envelope>
# in:<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
# in:  <soapenv:Body>
# in:    <soapenv:Fault>
# in:      <faultcode>soapenv:Client</faultcode>
# in:      <faultstring>Could not insert new row - duplicate value in a UNIQUE INDEX column (Unique Index:).</faultstring>
# in:      <detail>
# in:        <axlError>
# in:          <axlcode>-239</axlcode>
# in:          <axlmessage>Could not insert new row - duplicate value in a UNIQUE INDEX column (Unique Index:).</axlmessage>
# in:          <request>addUser</request>
# in:        </axlError>
# in:      </detail>
# in:    </soapenv:Fault>
# in:  </soapenv:Body>
# in:</soapenv:Envelope>
# Failed to insert user: -239/Could not insert new row - duplicate value in a UNIQUE INDEX column (Unique Index:).
